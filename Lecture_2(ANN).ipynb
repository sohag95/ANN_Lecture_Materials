# %% [markdown]
# # **Recap of Previous Lecture ⬇**

# %% [markdown]
# ## **Artificial Neural Network (ANN) Architecture**
#
# The diagram below illustrates the structure of an Artificial Neural Network (ANN), including the input layer, hidden layers, and output layer. It visually represents how data flows through neurons, with connections (weights) adjusting during training to improve predictions.
#
#
# ![ANN Diagram](https://i0.wp.com/i.postimg.cc/rmZkmFJ2/Artificial-neural-network-architecture-ANN-i-h-1-h-2-h-n-o.png?resize=710%2C416&ssl=1)

# %% [markdown]
# ### **Building Blocks of ANN**
#
# | **Category** | **Components & Definitions** |
# | ----- | ----- |
# | **Neural Units** | **Neuron (Perceptron), Node, Unit →** Fundamental units that process inputs and pass signals forward. |
# | **Weights & Bias** | 	**Weights (w), Bias(b) →** Learnable parameters that adjust how inputs influence outputs. |
# | **Layers** | 	**Input Layer, Hidden Layer, Output Layer →** Different stages where data is processed and transformed. |
# | **Activation Functions** | **ReLU, Sigmoid, Tanh, Softmax →** Functions that introduce non-linearity and help in learning complex patterns. |
# | **Learning Process** | **Forward Propagation, Backpropagation, Loss Function →** The mechanism of learning by adjusting weights based on errors.|
# | **Optimization** | **Optimizer, Gradient Descent, Adam, RMSprop →** Algorithms that update weights to minimize loss. |
# | **Hyperparameters** | **Learning Rate, Epochs, Batch Size →** Parameters set before training to control how the model learns. |
# | **Regularization** | **Dropout, L1/L2 Regularization (Lasso, Ridge) →** Techniques to prevent overfitting by controlling weights. |
#
#
# > **Note:** We will go through each of these building blocks in detail to gain a better understanding of the ANN architecture.
# >

# %% [markdown]
# ### **Perceptron Architecture**
# The diagram below illustrates the structure of a perceptron, showcasing how inputs are weighted, summed, and passed through an activation function to produce an output.
#
#
# ![Perceptron](https://aiml.com/wp-content/uploads/2023/09/perceptron-a-neuron-2.png)
#
# ### **Perceptron Training Algorithm**
# The following algorithm outlines the steps involved in training a perceptron, where weights are adjusted iteratively based on errors to achieve accurate classification.
#
# **The process typically follows these steps:**
#
# * **Initialize weights:** Set initial weights randomly.
#
# * **Forward pass:** Compute the weighted sum of inputs and pass it through an activation function.
#
# * **Calculate error:** Compare the predicted output with the actual target.
#
# * **Update weights:** Adjust weights based on the error using a learning rate and the gradient descent algorithm.
#
# * **Repeat:** Iterate through the dataset multiple times(epochs) until the more converges.

# %% [markdown]
# ## **Geometric Intuition of MLP**
# Before diving into the mathematical details of forward and backward propagation, let’s first develop an intuitive understanding of how a Multi-Layer Perceptron (MLP) transforms data in a geometric sense.
#
# An MLP applies a series of linear transformations (matrix multiplications) followed by non-linear activations. This process helps in learning complex decision boundaries, making it capable of solving classification and regression tasks.
#
# To visualize how an MLP learns to separate data in high-dimensional space, explore the interactive demonstration below:
#
# 🔗 [MLP Geometric Intuition Demo](https://playground.tensorflow.org/)
#
# 👉 Click the link above to see how different MLP architectures transform data and learn decision boundaries in real-time!

# %% [markdown]
# # **Lecture 2: Forward and Backward Propagation in a 2-Layer MLP**

# %% [markdown]
# ![Ann_single](https://github.com/sohag95/ANN_Lecture_Materials/blob/main/matrix.jpg?raw=true)
#
# **Understanding the Flow of Information in a Multi-Layer Perceptron (MLP)**
#
# The diagram below represents a 2-layer MLP architecture, consisting of an input layer, one hidden layer, and an output layer. We will now analyze how data flows through this network during:
#
# * **Forward Propagation –** Computing activations layer by layer.
#
# * **Backward Propagation –** Updating weights using gradients.
#
# **1. Forward Propagation:**
#
# 1. Input features pass through the first layer, where weights and biases transform them.
#
# 2. The activation function (e.g., ReLU, Sigmoid) is applied to introduce non-linearity.
#
# 3. The process repeats for the output layer to compute final predictions.
#
# **2. Backward Propagation:**
#
# 1. The loss function measures the error between predicted and actual outputs.
#
# 2. Gradients of the loss w.r.t. weights are computed using the chain rule.
#
# 3. The weights are updated using an optimization algorithm like Gradient Descent.
#
# This understanding is crucial for training neural networks effectively. Now, let’s dive into the mathematical formulation of each step.

# %% [markdown]
# ## ✍**Lecture Notes on Forward and Backward Propagation**
# For a detailed explanation of forward and backward propagation in a 2-layer MLP, refer to the lecture notes provided in the PDF below. This document covers the step-by-step derivations, mathematical formulations, and key insights into how gradients are computed and used for weight updates.
#
# 📄 [Download Lecture Notes](https://github.com/sohag95/ANN_Lecture_Materials/blob/main/Lab%20Neural%20Net.pdf)
# **(provided by Br. Tamal Maharaj)**
#
# Click the link above to access the notes. Reviewing this material will help reinforce the concepts discussed in the lecture!

# %% [markdown]
# # **Implementation of Forward and Backward Propagation in a 2-Layer MLP**

# %% [markdown]
# ## Warm-up: numpy
# Before introducing PyTorch, we will first implement the network using numpy.
#
# Numpy provides an n-dimensional array object, and many functions for manipulating these arrays. Numpy is a generic framework for scientific computing; it does not know anything about computation graphs, or deep learning, or gradients. However we can easily use numpy to fit a two-layer network to random data by manually implementing the forward and backward passes through the network using numpy operations:

# %%
# Code in file tensor/two_layer_net_numpy.py
import numpy as np

# N is batch size; D_in is input dimension;
# H is hidden dimension; D_out is output dimension.
N, D_in, H, D_out = 64, 1000, 100, 10

# Create random input and output data
x = np.random.randn(N, D_in)
y = np.random.randn(N, D_out)

# Randomly initialize weights
w1 = np.random.randn(D_in, H)
w2 = np.random.randn(H, D_out)

# %%
learning_rate = 1e-6
for t in range(500):
  # Forward pass: compute predicted y
  h = x.dot(w1)
  h_relu = np.maximum(h, 0)
  y_pred = h_relu.dot(w2)

  # Compute and print loss
  loss = np.square(y_pred - y).sum()
  print(f"Iteration {t}: Loss = {loss:.6f}")

  # Backprop to compute gradients of w1 and w2 with respect to loss
  grad_y_pred = 2.0 * (y_pred - y)
  grad_w2 = h_relu.T.dot(grad_y_pred)
  grad_h_relu = grad_y_pred.dot(w2.T)
  grad_h = grad_h_relu.copy()
  grad_h[h < 0] = 0
  grad_w1 = x.T.dot(grad_h)

  # Update weights
  w1 -= learning_rate * grad_w1
  w2 -= learning_rate * grad_w2
# Out:
# Iteration 0: Loss = 41562340.899624
# Iteration 1: Loss = 44499987.138660
# Iteration 2: Loss = 50702481.330080
# Iteration 3: Loss = 48111419.668701
# Iteration 4: Loss = 32639419.871779
# Iteration 5: Loss = 15578652.920235
# Iteration 6: Loss = 6337092.426986
# Iteration 7: Loss = 2990065.997808
# Iteration 8: Loss = 1862371.708903
# Iteration 9: Loss = 1397678.237552
# Iteration 10: Loss = 1137021.582692
# Iteration 11: Loss = 955390.518012
# Iteration 12: Loss = 815099.456147
# Iteration 13: Loss = 701879.227962
# Iteration 14: Loss = 608618.471690
# Iteration 15: Loss = 530840.110504
# Iteration 16: Loss = 465419.691936
# Iteration 17: Loss = 409962.916863
# Iteration 18: Loss = 362648.403355
# Iteration 19: Loss = 322044.159590
# Iteration 20: Loss = 286955.263990
# Iteration 21: Loss = 256508.068581
# Iteration 22: Loss = 229987.773369
# Iteration 23: Loss = 206821.786190
# Iteration 24: Loss = 186447.209760
# Iteration 25: Loss = 168465.793223
# Iteration 26: Loss = 152505.845589
# Iteration 27: Loss = 138360.050377
# Iteration 28: Loss = 125757.706098
# Iteration 29: Loss = 114511.701315
# Iteration 30: Loss = 104440.178792
# Iteration 31: Loss = 95415.239708
# Iteration 32: Loss = 87300.352114
# Iteration 33: Loss = 79985.787430
# Iteration 34: Loss = 73374.686022
# Iteration 35: Loss = 67387.869569
# Iteration 36: Loss = 61961.246466
# Iteration 37: Loss = 57034.874051
# Iteration 38: Loss = 52551.663444
# Iteration 39: Loss = 48467.432090
# Iteration 40: Loss = 44741.758450
# Iteration 41: Loss = 41340.117354
# Iteration 42: Loss = 38229.781846
# Iteration 43: Loss = 35383.048904
# Iteration 44: Loss = 32771.286856
# Iteration 45: Loss = 30373.398405
# Iteration 46: Loss = 28170.962623
# Iteration 47: Loss = 26145.555119
# Iteration 48: Loss = 24281.408603
# Iteration 49: Loss = 22563.304522
# Iteration 50: Loss = 20975.870883
# Iteration 51: Loss = 19512.948777
# Iteration 52: Loss = 18160.563673
# Iteration 53: Loss = 16911.142672
# Iteration 54: Loss = 15754.880970
# Iteration 55: Loss = 14684.398249
# Iteration 56: Loss = 13693.491011
# Iteration 57: Loss = 12774.522110
# Iteration 58: Loss = 11922.879961
# Iteration 59: Loss = 11132.363128
# Iteration 60: Loss = 10398.253418
# Iteration 61: Loss = 9716.198691
# Iteration 62: Loss = 9082.248189
# Iteration 63: Loss = 8493.013383
# Iteration 64: Loss = 7944.386802
# Iteration 65: Loss = 7433.678466
# Iteration 66: Loss = 6958.292292
# Iteration 67: Loss = 6515.571034
# Iteration 68: Loss = 6102.789316
# Iteration 69: Loss = 5717.700936
# Iteration 70: Loss = 5358.539437
# Iteration 71: Loss = 5023.498380
# Iteration 72: Loss = 4710.530058
# Iteration 73: Loss = 4418.296644
# Iteration 74: Loss = 4145.232018
# Iteration 75: Loss = 3890.109769
# Iteration 76: Loss = 3651.465781
# Iteration 77: Loss = 3428.335340
# Iteration 78: Loss = 3219.667026
# Iteration 79: Loss = 3024.292417
# Iteration 80: Loss = 2841.452992
# Iteration 81: Loss = 2670.249326
# Iteration 82: Loss = 2509.905609
# Iteration 83: Loss = 2359.642122
# Iteration 84: Loss = 2218.792052
# Iteration 85: Loss = 2086.814064
# Iteration 86: Loss = 1963.055006
# Iteration 87: Loss = 1847.165281
# Iteration 88: Loss = 1738.590399
# Iteration 89: Loss = 1636.693351
# Iteration 90: Loss = 1541.095170
# Iteration 91: Loss = 1451.361532
# Iteration 92: Loss = 1367.044059
# Iteration 93: Loss = 1287.847381
# Iteration 94: Loss = 1213.522234
# Iteration 95: Loss = 1143.675832
# Iteration 96: Loss = 1077.958041
# Iteration 97: Loss = 1016.164642
# Iteration 98: Loss = 958.062017
# Iteration 99: Loss = 903.418252
# Iteration 100: Loss = 852.068883
# Iteration 101: Loss = 803.728077
# Iteration 102: Loss = 758.223427
# Iteration 103: Loss = 715.381538
# Iteration 104: Loss = 675.071063
# Iteration 105: Loss = 637.111608
# Iteration 106: Loss = 601.373325
# Iteration 107: Loss = 567.705132
# Iteration 108: Loss = 535.989877
# Iteration 109: Loss = 506.108212
# Iteration 110: Loss = 477.944142
# Iteration 111: Loss = 451.416113
# Iteration 112: Loss = 426.403215
# Iteration 113: Loss = 402.826920
# Iteration 114: Loss = 380.596556
# Iteration 115: Loss = 359.629801
# Iteration 116: Loss = 339.902637
# Iteration 117: Loss = 321.309019
# Iteration 118: Loss = 303.757448
# Iteration 119: Loss = 287.114770
# Iteration 120: Loss = 271.413914
# Iteration 121: Loss = 256.606429
# Iteration 122: Loss = 242.629988
# Iteration 123: Loss = 229.442591
# Iteration 124: Loss = 216.993004
# Iteration 125: Loss = 205.238593
# Iteration 126: Loss = 194.139573
# Iteration 127: Loss = 183.660357
# Iteration 128: Loss = 173.767867
# Iteration 129: Loss = 164.420442
# Iteration 130: Loss = 155.588889
# Iteration 131: Loss = 147.247106
# Iteration 132: Loss = 139.362780
# Iteration 133: Loss = 131.912499
# Iteration 134: Loss = 124.876161
# Iteration 135: Loss = 118.221333
# Iteration 136: Loss = 111.932441
# Iteration 137: Loss = 105.987355
# Iteration 138: Loss = 100.368742
# Iteration 139: Loss = 95.052787
# Iteration 140: Loss = 90.025796
# Iteration 141: Loss = 85.271024
# Iteration 142: Loss = 80.775613
# Iteration 143: Loss = 76.522942
# Iteration 144: Loss = 72.500016
# Iteration 145: Loss = 68.692813
# Iteration 146: Loss = 65.089681
# Iteration 147: Loss = 61.680549
# Iteration 148: Loss = 58.454542
# Iteration 149: Loss = 55.401169
# Iteration 150: Loss = 52.511615
# Iteration 151: Loss = 49.775593
# Iteration 152: Loss = 47.185409
# Iteration 153: Loss = 44.732673
# Iteration 154: Loss = 42.413873
# Iteration 155: Loss = 40.214377
# Iteration 156: Loss = 38.131348
# Iteration 157: Loss = 36.159297
# Iteration 158: Loss = 34.291552
# Iteration 159: Loss = 32.522642
# Iteration 160: Loss = 30.846995
# Iteration 161: Loss = 29.258603
# Iteration 162: Loss = 27.753826
# Iteration 163: Loss = 26.328369
# Iteration 164: Loss = 24.977655
# Iteration 165: Loss = 23.697590
# Iteration 166: Loss = 22.484554
# Iteration 167: Loss = 21.335402
# Iteration 168: Loss = 20.245895
# Iteration 169: Loss = 19.212307
# Iteration 170: Loss = 18.232885
# Iteration 171: Loss = 17.304939
# Iteration 172: Loss = 16.424639
# Iteration 173: Loss = 15.590066
# Iteration 174: Loss = 14.798360
# Iteration 175: Loss = 14.047864
# Iteration 176: Loss = 13.336134
# Iteration 177: Loss = 12.661434
# Iteration 178: Loss = 12.020943
# Iteration 179: Loss = 11.413665
# Iteration 180: Loss = 10.837689
# Iteration 181: Loss = 10.291371
# Iteration 182: Loss = 9.773011
# Iteration 183: Loss = 9.281245
# Iteration 184: Loss = 8.814470
# Iteration 185: Loss = 8.371587
# Iteration 186: Loss = 7.951413
# Iteration 187: Loss = 7.552779
# Iteration 188: Loss = 7.174243
# Iteration 189: Loss = 6.815252
# Iteration 190: Loss = 6.474485
# Iteration 191: Loss = 6.150890
# Iteration 192: Loss = 5.843667
# Iteration 193: Loss = 5.552139
# Iteration 194: Loss = 5.275527
# Iteration 195: Loss = 5.012854
# Iteration 196: Loss = 4.763380
# Iteration 197: Loss = 4.526494
# Iteration 198: Loss = 4.301614
# Iteration 199: Loss = 4.088168
# Iteration 200: Loss = 3.885387
# Iteration 201: Loss = 3.692857
# Iteration 202: Loss = 3.509907
# Iteration 203: Loss = 3.336247
# Iteration 204: Loss = 3.171287
# Iteration 205: Loss = 3.014551
# Iteration 206: Loss = 2.865665
# Iteration 207: Loss = 2.724396
# Iteration 208: Loss = 2.590098
# Iteration 209: Loss = 2.462521
# Iteration 210: Loss = 2.341336
# Iteration 211: Loss = 2.226181
# Iteration 212: Loss = 2.116740
# Iteration 213: Loss = 2.012772
# Iteration 214: Loss = 1.913993
# Iteration 215: Loss = 1.820119
# Iteration 216: Loss = 1.730911
# Iteration 217: Loss = 1.646108
# Iteration 218: Loss = 1.565502
# Iteration 219: Loss = 1.488969
# Iteration 220: Loss = 1.416222
# Iteration 221: Loss = 1.347038
# Iteration 222: Loss = 1.281262
# Iteration 223: Loss = 1.218739
# Iteration 224: Loss = 1.159330
# Iteration 225: Loss = 1.102871
# Iteration 226: Loss = 1.049205
# Iteration 227: Loss = 0.998164
# Iteration 228: Loss = 0.949621
# Iteration 229: Loss = 0.903473
# Iteration 230: Loss = 0.859593
# Iteration 231: Loss = 0.817865
# Iteration 232: Loss = 0.778218
# Iteration 233: Loss = 0.740489
# Iteration 234: Loss = 0.704619
# Iteration 235: Loss = 0.670499
# Iteration 236: Loss = 0.638052
# Iteration 237: Loss = 0.607196
# Iteration 238: Loss = 0.577858
# Iteration 239: Loss = 0.549947
# Iteration 240: Loss = 0.523414
# Iteration 241: Loss = 0.498172
# Iteration 242: Loss = 0.474154
# Iteration 243: Loss = 0.451301
# Iteration 244: Loss = 0.429570
# Iteration 245: Loss = 0.408893
# Iteration 246: Loss = 0.389217
# Iteration 247: Loss = 0.370508
# Iteration 248: Loss = 0.352705
# Iteration 249: Loss = 0.335761
# Iteration 250: Loss = 0.319641
# Iteration 251: Loss = 0.304312
# Iteration 252: Loss = 0.289721
# Iteration 253: Loss = 0.275836
# Iteration 254: Loss = 0.262622
# Iteration 255: Loss = 0.250050
# Iteration 256: Loss = 0.238089
# Iteration 257: Loss = 0.226698
# Iteration 258: Loss = 0.215865
# Iteration 259: Loss = 0.205555
# Iteration 260: Loss = 0.195743
# Iteration 261: Loss = 0.186397
# Iteration 262: Loss = 0.177503
# Iteration 263: Loss = 0.169038
# Iteration 264: Loss = 0.160983
# Iteration 265: Loss = 0.153317
# Iteration 266: Loss = 0.146019
# Iteration 267: Loss = 0.139070
# Iteration 268: Loss = 0.132454
# Iteration 269: Loss = 0.126154
# Iteration 270: Loss = 0.120157
# Iteration 271: Loss = 0.114455
# Iteration 272: Loss = 0.109022
# Iteration 273: Loss = 0.103847
# Iteration 274: Loss = 0.098922
# Iteration 275: Loss = 0.094233
# Iteration 276: Loss = 0.089766
# Iteration 277: Loss = 0.085514
# Iteration 278: Loss = 0.081466
# Iteration 279: Loss = 0.077610
# Iteration 280: Loss = 0.073939
# Iteration 281: Loss = 0.070442
# Iteration 282: Loss = 0.067112
# Iteration 283: Loss = 0.063942
# Iteration 284: Loss = 0.060922
# Iteration 285: Loss = 0.058046
# Iteration 286: Loss = 0.055307
# Iteration 287: Loss = 0.052700
# Iteration 288: Loss = 0.050215
# Iteration 289: Loss = 0.047848
# Iteration 290: Loss = 0.045594
# Iteration 291: Loss = 0.043449
# Iteration 292: Loss = 0.041404
# Iteration 293: Loss = 0.039455
# Iteration 294: Loss = 0.037599
# Iteration 295: Loss = 0.035832
# Iteration 296: Loss = 0.034148
# Iteration 297: Loss = 0.032544
# Iteration 298: Loss = 0.031015
# Iteration 299: Loss = 0.029560
# Iteration 300: Loss = 0.028173
# Iteration 301: Loss = 0.026852
# Iteration 302: Loss = 0.025593
# Iteration 303: Loss = 0.024394
# Iteration 304: Loss = 0.023251
# Iteration 305: Loss = 0.022162
# Iteration 306: Loss = 0.021124
# Iteration 307: Loss = 0.020135
# Iteration 308: Loss = 0.019193
# Iteration 309: Loss = 0.018296
# Iteration 310: Loss = 0.017441
# Iteration 311: Loss = 0.016626
# Iteration 312: Loss = 0.015850
# Iteration 313: Loss = 0.015109
# Iteration 314: Loss = 0.014404
# Iteration 315: Loss = 0.013732
# Iteration 316: Loss = 0.013091
# Iteration 317: Loss = 0.012481
# Iteration 318: Loss = 0.011899
# Iteration 319: Loss = 0.011345
# Iteration 320: Loss = 0.010816
# Iteration 321: Loss = 0.010312
# Iteration 322: Loss = 0.009832
# Iteration 323: Loss = 0.009375
# Iteration 324: Loss = 0.008939
# Iteration 325: Loss = 0.008523
# Iteration 326: Loss = 0.008127
# Iteration 327: Loss = 0.007749
# Iteration 328: Loss = 0.007389
# Iteration 329: Loss = 0.007046
# Iteration 330: Loss = 0.006719
# Iteration 331: Loss = 0.006407
# Iteration 332: Loss = 0.006110
# Iteration 333: Loss = 0.005826
# Iteration 334: Loss = 0.005556
# Iteration 335: Loss = 0.005298
# Iteration 336: Loss = 0.005053
# Iteration 337: Loss = 0.004819
# Iteration 338: Loss = 0.004596
# Iteration 339: Loss = 0.004383
# Iteration 340: Loss = 0.004180
# Iteration 341: Loss = 0.003987
# Iteration 342: Loss = 0.003802
# Iteration 343: Loss = 0.003626
# Iteration 344: Loss = 0.003459
# Iteration 345: Loss = 0.003299
# Iteration 346: Loss = 0.003146
# Iteration 347: Loss = 0.003001
# Iteration 348: Loss = 0.002862
# Iteration 349: Loss = 0.002730
# Iteration 350: Loss = 0.002604
# Iteration 351: Loss = 0.002484
# Iteration 352: Loss = 0.002370
# Iteration 353: Loss = 0.002260
# Iteration 354: Loss = 0.002156
# Iteration 355: Loss = 0.002057
# Iteration 356: Loss = 0.001962
# Iteration 357: Loss = 0.001872
# Iteration 358: Loss = 0.001785
# Iteration 359: Loss = 0.001703
# Iteration 360: Loss = 0.001625
# Iteration 361: Loss = 0.001550
# Iteration 362: Loss = 0.001479
# Iteration 363: Loss = 0.001411
# Iteration 364: Loss = 0.001346
# Iteration 365: Loss = 0.001284
# Iteration 366: Loss = 0.001225
# Iteration 367: Loss = 0.001169
# Iteration 368: Loss = 0.001115
# Iteration 369: Loss = 0.001064
# Iteration 370: Loss = 0.001015
# Iteration 371: Loss = 0.000968
# Iteration 372: Loss = 0.000924
# Iteration 373: Loss = 0.000882
# Iteration 374: Loss = 0.000841
# Iteration 375: Loss = 0.000803
# Iteration 376: Loss = 0.000766
# Iteration 377: Loss = 0.000731
# Iteration 378: Loss = 0.000697
# Iteration 379: Loss = 0.000665
# Iteration 380: Loss = 0.000635
# Iteration 381: Loss = 0.000606
# Iteration 382: Loss = 0.000578
# Iteration 383: Loss = 0.000552
# Iteration 384: Loss = 0.000526
# Iteration 385: Loss = 0.000502
# Iteration 386: Loss = 0.000479
# Iteration 387: Loss = 0.000457
# Iteration 388: Loss = 0.000437
# Iteration 389: Loss = 0.000417
# Iteration 390: Loss = 0.000398
# Iteration 391: Loss = 0.000379
# Iteration 392: Loss = 0.000362
# Iteration 393: Loss = 0.000346
# Iteration 394: Loss = 0.000330
# Iteration 395: Loss = 0.000315
# Iteration 396: Loss = 0.000300
# Iteration 397: Loss = 0.000287
# Iteration 398: Loss = 0.000274
# Iteration 399: Loss = 0.000261
# Iteration 400: Loss = 0.000249
# Iteration 401: Loss = 0.000238
# Iteration 402: Loss = 0.000227
# Iteration 403: Loss = 0.000217
# Iteration 404: Loss = 0.000207
# Iteration 405: Loss = 0.000197
# Iteration 406: Loss = 0.000188
# Iteration 407: Loss = 0.000180
# Iteration 408: Loss = 0.000172
# Iteration 409: Loss = 0.000164
# Iteration 410: Loss = 0.000156
# Iteration 411: Loss = 0.000149
# Iteration 412: Loss = 0.000142
# Iteration 413: Loss = 0.000136
# Iteration 414: Loss = 0.000130
# Iteration 415: Loss = 0.000124
# Iteration 416: Loss = 0.000118
# Iteration 417: Loss = 0.000113
# Iteration 418: Loss = 0.000108
# Iteration 419: Loss = 0.000103
# Iteration 420: Loss = 0.000098
# Iteration 421: Loss = 0.000094
# Iteration 422: Loss = 0.000090
# Iteration 423: Loss = 0.000085
# Iteration 424: Loss = 0.000082
# Iteration 425: Loss = 0.000078
# Iteration 426: Loss = 0.000074
# Iteration 427: Loss = 0.000071
# Iteration 428: Loss = 0.000068
# Iteration 429: Loss = 0.000065
# Iteration 430: Loss = 0.000062
# Iteration 431: Loss = 0.000059
# Iteration 432: Loss = 0.000056
# Iteration 433: Loss = 0.000054
# Iteration 434: Loss = 0.000051
# Iteration 435: Loss = 0.000049
# Iteration 436: Loss = 0.000047
# Iteration 437: Loss = 0.000045
# Iteration 438: Loss = 0.000043
# Iteration 439: Loss = 0.000041
# Iteration 440: Loss = 0.000039
# Iteration 441: Loss = 0.000037
# Iteration 442: Loss = 0.000035
# Iteration 443: Loss = 0.000034
# Iteration 444: Loss = 0.000032
# Iteration 445: Loss = 0.000031
# Iteration 446: Loss = 0.000029
# Iteration 447: Loss = 0.000028
# Iteration 448: Loss = 0.000027
# Iteration 449: Loss = 0.000026
# Iteration 450: Loss = 0.000024
# Iteration 451: Loss = 0.000023
# Iteration 452: Loss = 0.000022
# Iteration 453: Loss = 0.000021
# Iteration 454: Loss = 0.000020
# Iteration 455: Loss = 0.000019
# Iteration 456: Loss = 0.000019
# Iteration 457: Loss = 0.000018
# Iteration 458: Loss = 0.000017
# Iteration 459: Loss = 0.000016
# Iteration 460: Loss = 0.000015
# Iteration 461: Loss = 0.000015
# Iteration 462: Loss = 0.000014
# Iteration 463: Loss = 0.000013
# Iteration 464: Loss = 0.000013
# Iteration 465: Loss = 0.000012
# Iteration 466: Loss = 0.000012
# Iteration 467: Loss = 0.000011
# Iteration 468: Loss = 0.000011
# Iteration 469: Loss = 0.000010
# Iteration 470: Loss = 0.000010
# Iteration 471: Loss = 0.000009
# Iteration 472: Loss = 0.000009
# Iteration 473: Loss = 0.000008
# Iteration 474: Loss = 0.000008
# Iteration 475: Loss = 0.000008
# Iteration 476: Loss = 0.000007
# Iteration 477: Loss = 0.000007
# Iteration 478: Loss = 0.000007
# Iteration 479: Loss = 0.000006
# Iteration 480: Loss = 0.000006
# Iteration 481: Loss = 0.000006
# Iteration 482: Loss = 0.000006
# Iteration 483: Loss = 0.000005
# Iteration 484: Loss = 0.000005
# Iteration 485: Loss = 0.000005
# Iteration 486: Loss = 0.000005
# Iteration 487: Loss = 0.000004
# Iteration 488: Loss = 0.000004
# Iteration 489: Loss = 0.000004
# Iteration 490: Loss = 0.000004
# Iteration 491: Loss = 0.000004
# Iteration 492: Loss = 0.000004
# Iteration 493: Loss = 0.000003
# Iteration 494: Loss = 0.000003
# Iteration 495: Loss = 0.000003
# Iteration 496: Loss = 0.000003
# Iteration 497: Loss = 0.000003
# Iteration 498: Loss = 0.000003
# Iteration 499: Loss = 0.000003

# %% [markdown]
# ### **Extending MLP Implementation: Adding Bias Terms to Forward and Backward Propagation**

# %%
import numpy as np

# N is batch size; D_in is input dimension;
# H is hidden dimension; D_out is output dimension.
N, D_in, H, D_out = 64, 1000, 100, 10

# Create random input and output data
x = np.random.randn(N, D_in)
y = np.random.randn(N, D_out)

# Randomly initialize weights and biases
w1 = np.random.randn(D_in, H)
b1 = np.zeros((1, H))  # Bias for hidden layer
w2 = np.random.randn(H, D_out)
b2 = np.zeros((1, D_out))  # Bias for output layer

learning_rate = 1e-6
for t in range(500):
    # Forward pass: compute predicted y
    h = x.dot(w1) + b1  # Adding bias term
    h_relu = np.maximum(h, 0)
    y_pred = h_relu.dot(w2) + b2  # Adding bias term

    # Compute and print loss
    loss = np.square(y_pred - y).sum()
    print(f"Iteration {t}: Loss = {loss:.6f}")

    # Backprop to compute gradients
    grad_y_pred = 2.0 * (y_pred - y)
    grad_w2 = h_relu.T.dot(grad_y_pred)
    grad_b2 = np.sum(grad_y_pred, axis=0, keepdims=True)

    grad_h_relu = grad_y_pred.dot(w2.T)
    grad_h = grad_h_relu.copy()
    grad_h[h < 0] = 0

    grad_w1 = x.T.dot(grad_h)
    grad_b1 = np.sum(grad_h, axis=0, keepdims=True)

    # Update weights and biases
    w1 -= learning_rate * grad_w1
    b1 -= learning_rate * grad_b1
    w2 -= learning_rate * grad_w2
    b2 -= learning_rate * grad_b2
# Out:
# Iteration 0: Loss = 37865598.259198
# Iteration 1: Loss = 33721822.564776
# Iteration 2: Loss = 31801351.251798
# Iteration 3: Loss = 27065982.656061
# Iteration 4: Loss = 19503505.124063
# Iteration 5: Loss = 11951835.828404
# Iteration 6: Loss = 6736787.222641
# Iteration 7: Loss = 3847463.146075
# Iteration 8: Loss = 2392605.467024
# Iteration 9: Loss = 1650190.756852
# Iteration 10: Loss = 1239710.186026
# Iteration 11: Loss = 985535.959410
# Iteration 12: Loss = 811392.711802
# Iteration 13: Loss = 681817.567590
# Iteration 14: Loss = 580302.398593
# Iteration 15: Loss = 498549.438831
# Iteration 16: Loss = 431112.857068
# Iteration 17: Loss = 374773.170976
# Iteration 18: Loss = 327322.339609
# Iteration 19: Loss = 287052.211527
# Iteration 20: Loss = 252656.862095
# Iteration 21: Loss = 223091.758009
# Iteration 22: Loss = 197568.397756
# Iteration 23: Loss = 175458.085238
# Iteration 24: Loss = 156215.893077
# Iteration 25: Loss = 139421.322066
# Iteration 26: Loss = 124705.804943
# Iteration 27: Loss = 111769.681655
# Iteration 28: Loss = 100366.550322
# Iteration 29: Loss = 90304.402437
# Iteration 30: Loss = 81394.219447
# Iteration 31: Loss = 73492.078549
# Iteration 32: Loss = 66494.197845
# Iteration 33: Loss = 60260.536761
# Iteration 34: Loss = 54688.970358
# Iteration 35: Loss = 49701.295585
# Iteration 36: Loss = 45225.589749
# Iteration 37: Loss = 41202.418275
# Iteration 38: Loss = 37580.634512
# Iteration 39: Loss = 34315.304685
# Iteration 40: Loss = 31369.258990
# Iteration 41: Loss = 28707.522853
# Iteration 42: Loss = 26297.385075
# Iteration 43: Loss = 24112.461559
# Iteration 44: Loss = 22129.762518
# Iteration 45: Loss = 20329.098496
# Iteration 46: Loss = 18686.825746
# Iteration 47: Loss = 17193.057133
# Iteration 48: Loss = 15834.091791
# Iteration 49: Loss = 14594.385523
# Iteration 50: Loss = 13462.611820
# Iteration 51: Loss = 12428.160546
# Iteration 52: Loss = 11481.901368
# Iteration 53: Loss = 10615.287689
# Iteration 54: Loss = 9821.050586
# Iteration 55: Loss = 9092.722506
# Iteration 56: Loss = 8423.958373
# Iteration 57: Loss = 7809.378018
# Iteration 58: Loss = 7244.246757
# Iteration 59: Loss = 6724.343015
# Iteration 60: Loss = 6245.497681
# Iteration 61: Loss = 5803.912580
# Iteration 62: Loss = 5396.808111
# Iteration 63: Loss = 5021.799077
# Iteration 64: Loss = 4675.665305
# Iteration 65: Loss = 4355.720836
# Iteration 66: Loss = 4059.958267
# Iteration 67: Loss = 3786.258295
# Iteration 68: Loss = 3532.716800
# Iteration 69: Loss = 3297.728111
# Iteration 70: Loss = 3079.840669
# Iteration 71: Loss = 2877.769858
# Iteration 72: Loss = 2690.206263
# Iteration 73: Loss = 2515.971071
# Iteration 74: Loss = 2354.361196
# Iteration 75: Loss = 2204.638020
# Iteration 76: Loss = 2065.297459
# Iteration 77: Loss = 1935.545410
# Iteration 78: Loss = 1814.720346
# Iteration 79: Loss = 1702.167180
# Iteration 80: Loss = 1597.254534
# Iteration 81: Loss = 1499.295996
# Iteration 82: Loss = 1407.913115
# Iteration 83: Loss = 1322.575225
# Iteration 84: Loss = 1242.823540
# Iteration 85: Loss = 1168.279257
# Iteration 86: Loss = 1098.593956
# Iteration 87: Loss = 1033.393582
# Iteration 88: Loss = 972.399881
# Iteration 89: Loss = 915.325807
# Iteration 90: Loss = 861.888047
# Iteration 91: Loss = 811.794305
# Iteration 92: Loss = 764.845580
# Iteration 93: Loss = 720.831380
# Iteration 94: Loss = 679.539595
# Iteration 95: Loss = 640.801259
# Iteration 96: Loss = 604.450172
# Iteration 97: Loss = 570.316998
# Iteration 98: Loss = 538.272546
# Iteration 99: Loss = 508.165012
# Iteration 100: Loss = 479.866597
# Iteration 101: Loss = 453.252971
# Iteration 102: Loss = 428.226343
# Iteration 103: Loss = 404.693691
# Iteration 104: Loss = 382.541155
# Iteration 105: Loss = 361.687215
# Iteration 106: Loss = 342.056970
# Iteration 107: Loss = 323.568704
# Iteration 108: Loss = 306.149842
# Iteration 109: Loss = 289.732587
# Iteration 110: Loss = 274.259820
# Iteration 111: Loss = 259.667877
# Iteration 112: Loss = 245.907515
# Iteration 113: Loss = 232.925334
# Iteration 114: Loss = 220.675282
# Iteration 115: Loss = 209.114527
# Iteration 116: Loss = 198.197545
# Iteration 117: Loss = 187.890142
# Iteration 118: Loss = 178.153234
# Iteration 119: Loss = 168.957109
# Iteration 120: Loss = 160.267184
# Iteration 121: Loss = 152.058336
# Iteration 122: Loss = 144.298233
# Iteration 123: Loss = 136.959347
# Iteration 124: Loss = 130.016872
# Iteration 125: Loss = 123.446552
# Iteration 126: Loss = 117.228642
# Iteration 127: Loss = 111.344388
# Iteration 128: Loss = 105.775337
# Iteration 129: Loss = 100.501697
# Iteration 130: Loss = 95.504371
# Iteration 131: Loss = 90.771380
# Iteration 132: Loss = 86.286289
# Iteration 133: Loss = 82.034755
# Iteration 134: Loss = 78.005310
# Iteration 135: Loss = 74.189718
# Iteration 136: Loss = 70.568841
# Iteration 137: Loss = 67.133077
# Iteration 138: Loss = 63.874019
# Iteration 139: Loss = 60.782704
# Iteration 140: Loss = 57.849228
# Iteration 141: Loss = 55.064789
# Iteration 142: Loss = 52.422825
# Iteration 143: Loss = 49.913727
# Iteration 144: Loss = 47.530739
# Iteration 145: Loss = 45.267543
# Iteration 146: Loss = 43.118455
# Iteration 147: Loss = 41.076312
# Iteration 148: Loss = 39.135225
# Iteration 149: Loss = 37.290896
# Iteration 150: Loss = 35.538131
# Iteration 151: Loss = 33.871794
# Iteration 152: Loss = 32.288174
# Iteration 153: Loss = 30.781518
# Iteration 154: Loss = 29.348338
# Iteration 155: Loss = 27.985058
# Iteration 156: Loss = 26.688412
# Iteration 157: Loss = 25.454608
# Iteration 158: Loss = 24.280566
# Iteration 159: Loss = 23.163066
# Iteration 160: Loss = 22.099128
# Iteration 161: Loss = 21.086409
# Iteration 162: Loss = 20.122100
# Iteration 163: Loss = 19.204142
# Iteration 164: Loss = 18.329669
# Iteration 165: Loss = 17.496653
# Iteration 166: Loss = 16.703441
# Iteration 167: Loss = 15.947383
# Iteration 168: Loss = 15.227031
# Iteration 169: Loss = 14.540607
# Iteration 170: Loss = 13.886687
# Iteration 171: Loss = 13.262992
# Iteration 172: Loss = 12.668468
# Iteration 173: Loss = 12.101766
# Iteration 174: Loss = 11.561511
# Iteration 175: Loss = 11.046180
# Iteration 176: Loss = 10.554724
# Iteration 177: Loss = 10.085964
# Iteration 178: Loss = 9.638762
# Iteration 179: Loss = 9.212112
# Iteration 180: Loss = 8.805048
# Iteration 181: Loss = 8.416665
# Iteration 182: Loss = 8.046154
# Iteration 183: Loss = 7.692445
# Iteration 184: Loss = 7.354799
# Iteration 185: Loss = 7.032453
# Iteration 186: Loss = 6.724829
# Iteration 187: Loss = 6.431072
# Iteration 188: Loss = 6.150643
# Iteration 189: Loss = 5.882779
# Iteration 190: Loss = 5.627098
# Iteration 191: Loss = 5.382759
# Iteration 192: Loss = 5.149378
# Iteration 193: Loss = 4.926488
# Iteration 194: Loss = 4.713512
# Iteration 195: Loss = 4.510010
# Iteration 196: Loss = 4.315607
# Iteration 197: Loss = 4.129859
# Iteration 198: Loss = 3.952377
# Iteration 199: Loss = 3.782688
# Iteration 200: Loss = 3.620536
# Iteration 201: Loss = 3.465524
# Iteration 202: Loss = 3.317333
# Iteration 203: Loss = 3.175671
# Iteration 204: Loss = 3.040210
# Iteration 205: Loss = 2.910693
# Iteration 206: Loss = 2.786895
# Iteration 207: Loss = 2.668506
# Iteration 208: Loss = 2.555255
# Iteration 209: Loss = 2.446937
# Iteration 210: Loss = 2.343338
# Iteration 211: Loss = 2.244228
# Iteration 212: Loss = 2.149426
# Iteration 213: Loss = 2.058743
# Iteration 214: Loss = 1.971990
# Iteration 215: Loss = 1.888960
# Iteration 216: Loss = 1.809526
# Iteration 217: Loss = 1.733492
# Iteration 218: Loss = 1.660745
# Iteration 219: Loss = 1.591133
# Iteration 220: Loss = 1.524498
# Iteration 221: Loss = 1.460725
# Iteration 222: Loss = 1.399698
# Iteration 223: Loss = 1.341255
# Iteration 224: Loss = 1.285311
# Iteration 225: Loss = 1.231756
# Iteration 226: Loss = 1.180475
# Iteration 227: Loss = 1.131381
# Iteration 228: Loss = 1.084383
# Iteration 229: Loss = 1.039390
# Iteration 230: Loss = 0.996291
# Iteration 231: Loss = 0.955014
# Iteration 232: Loss = 0.915477
# Iteration 233: Loss = 0.877612
# Iteration 234: Loss = 0.841345
# Iteration 235: Loss = 0.806605
# Iteration 236: Loss = 0.773330
# Iteration 237: Loss = 0.741463
# Iteration 238: Loss = 0.710929
# Iteration 239: Loss = 0.681675
# Iteration 240: Loss = 0.653646
# Iteration 241: Loss = 0.626792
# Iteration 242: Loss = 0.601059
# Iteration 243: Loss = 0.576407
# Iteration 244: Loss = 0.552789
# Iteration 245: Loss = 0.530156
# Iteration 246: Loss = 0.508460
# Iteration 247: Loss = 0.487667
# Iteration 248: Loss = 0.467740
# Iteration 249: Loss = 0.448640
# Iteration 250: Loss = 0.430333
# Iteration 251: Loss = 0.412791
# Iteration 252: Loss = 0.395976
# Iteration 253: Loss = 0.379855
# Iteration 254: Loss = 0.364400
# Iteration 255: Loss = 0.349583
# Iteration 256: Loss = 0.335377
# Iteration 257: Loss = 0.321758
# Iteration 258: Loss = 0.308702
# Iteration 259: Loss = 0.296185
# Iteration 260: Loss = 0.284180
# Iteration 261: Loss = 0.272671
# Iteration 262: Loss = 0.261634
# Iteration 263: Loss = 0.251049
# Iteration 264: Loss = 0.240900
# Iteration 265: Loss = 0.231169
# Iteration 266: Loss = 0.221836
# Iteration 267: Loss = 0.212884
# Iteration 268: Loss = 0.204297
# Iteration 269: Loss = 0.196062
# Iteration 270: Loss = 0.188163
# Iteration 271: Loss = 0.180587
# Iteration 272: Loss = 0.173321
# Iteration 273: Loss = 0.166351
# Iteration 274: Loss = 0.159665
# Iteration 275: Loss = 0.153250
# Iteration 276: Loss = 0.147097
# Iteration 277: Loss = 0.141193
# Iteration 278: Loss = 0.135531
# Iteration 279: Loss = 0.130099
# Iteration 280: Loss = 0.124886
# Iteration 281: Loss = 0.119884
# Iteration 282: Loss = 0.115084
# Iteration 283: Loss = 0.110480
# Iteration 284: Loss = 0.106061
# Iteration 285: Loss = 0.101821
# Iteration 286: Loss = 0.097755
# Iteration 287: Loss = 0.093851
# Iteration 288: Loss = 0.090105
# Iteration 289: Loss = 0.086509
# Iteration 290: Loss = 0.083059
# Iteration 291: Loss = 0.079748
# Iteration 292: Loss = 0.076571
# Iteration 293: Loss = 0.073521
# Iteration 294: Loss = 0.070594
# Iteration 295: Loss = 0.067785
# Iteration 296: Loss = 0.065089
# Iteration 297: Loss = 0.062501
# Iteration 298: Loss = 0.060017
# Iteration 299: Loss = 0.057633
# Iteration 300: Loss = 0.055344
# Iteration 301: Loss = 0.053147
# Iteration 302: Loss = 0.051038
# Iteration 303: Loss = 0.049014
# Iteration 304: Loss = 0.047070
# Iteration 305: Loss = 0.045205
# Iteration 306: Loss = 0.043414
# Iteration 307: Loss = 0.041695
# Iteration 308: Loss = 0.040045
# Iteration 309: Loss = 0.038460
# Iteration 310: Loss = 0.036938
# Iteration 311: Loss = 0.035478
# Iteration 312: Loss = 0.034075
# Iteration 313: Loss = 0.032729
# Iteration 314: Loss = 0.031435
# Iteration 315: Loss = 0.030194
# Iteration 316: Loss = 0.029002
# Iteration 317: Loss = 0.027857
# Iteration 318: Loss = 0.026759
# Iteration 319: Loss = 0.025703
# Iteration 320: Loss = 0.024690
# Iteration 321: Loss = 0.023717
# Iteration 322: Loss = 0.022782
# Iteration 323: Loss = 0.021885
# Iteration 324: Loss = 0.021023
# Iteration 325: Loss = 0.020195
# Iteration 326: Loss = 0.019400
# Iteration 327: Loss = 0.018637
# Iteration 328: Loss = 0.017904
# Iteration 329: Loss = 0.017200
# Iteration 330: Loss = 0.016524
# Iteration 331: Loss = 0.015875
# Iteration 332: Loss = 0.015251
# Iteration 333: Loss = 0.014652
# Iteration 334: Loss = 0.014077
# Iteration 335: Loss = 0.013524
# Iteration 336: Loss = 0.012994
# Iteration 337: Loss = 0.012484
# Iteration 338: Loss = 0.011994
# Iteration 339: Loss = 0.011524
# Iteration 340: Loss = 0.011072
# Iteration 341: Loss = 0.010638
# Iteration 342: Loss = 0.010222
# Iteration 343: Loss = 0.009821
# Iteration 344: Loss = 0.009437
# Iteration 345: Loss = 0.009067
# Iteration 346: Loss = 0.008712
# Iteration 347: Loss = 0.008371
# Iteration 348: Loss = 0.008044
# Iteration 349: Loss = 0.007729
# Iteration 350: Loss = 0.007427
# Iteration 351: Loss = 0.007136
# Iteration 352: Loss = 0.006857
# Iteration 353: Loss = 0.006590
# Iteration 354: Loss = 0.006332
# Iteration 355: Loss = 0.006085
# Iteration 356: Loss = 0.005847
# Iteration 357: Loss = 0.005619
# Iteration 358: Loss = 0.005399
# Iteration 359: Loss = 0.005189
# Iteration 360: Loss = 0.004986
# Iteration 361: Loss = 0.004792
# Iteration 362: Loss = 0.004605
# Iteration 363: Loss = 0.004425
# Iteration 364: Loss = 0.004253
# Iteration 365: Loss = 0.004087
# Iteration 366: Loss = 0.003928
# Iteration 367: Loss = 0.003775
# Iteration 368: Loss = 0.003628
# Iteration 369: Loss = 0.003486
# Iteration 370: Loss = 0.003351
# Iteration 371: Loss = 0.003220
# Iteration 372: Loss = 0.003095
# Iteration 373: Loss = 0.002974
# Iteration 374: Loss = 0.002859
# Iteration 375: Loss = 0.002747
# Iteration 376: Loss = 0.002640
# Iteration 377: Loss = 0.002538
# Iteration 378: Loss = 0.002439
# Iteration 379: Loss = 0.002344
# Iteration 380: Loss = 0.002253
# Iteration 381: Loss = 0.002166
# Iteration 382: Loss = 0.002081
# Iteration 383: Loss = 0.002001
# Iteration 384: Loss = 0.001923
# Iteration 385: Loss = 0.001848
# Iteration 386: Loss = 0.001776
# Iteration 387: Loss = 0.001707
# Iteration 388: Loss = 0.001641
# Iteration 389: Loss = 0.001577
# Iteration 390: Loss = 0.001516
# Iteration 391: Loss = 0.001457
# Iteration 392: Loss = 0.001401
# Iteration 393: Loss = 0.001346
# Iteration 394: Loss = 0.001294
# Iteration 395: Loss = 0.001244
# Iteration 396: Loss = 0.001196
# Iteration 397: Loss = 0.001149
# Iteration 398: Loss = 0.001105
# Iteration 399: Loss = 0.001062
# Iteration 400: Loss = 0.001021
# Iteration 401: Loss = 0.000981
# Iteration 402: Loss = 0.000943
# Iteration 403: Loss = 0.000907
# Iteration 404: Loss = 0.000872
# Iteration 405: Loss = 0.000838
# Iteration 406: Loss = 0.000805
# Iteration 407: Loss = 0.000774
# Iteration 408: Loss = 0.000744
# Iteration 409: Loss = 0.000715
# Iteration 410: Loss = 0.000688
# Iteration 411: Loss = 0.000661
# Iteration 412: Loss = 0.000636
# Iteration 413: Loss = 0.000611
# Iteration 414: Loss = 0.000587
# Iteration 415: Loss = 0.000565
# Iteration 416: Loss = 0.000543
# Iteration 417: Loss = 0.000522
# Iteration 418: Loss = 0.000502
# Iteration 419: Loss = 0.000482
# Iteration 420: Loss = 0.000464
# Iteration 421: Loss = 0.000446
# Iteration 422: Loss = 0.000428
# Iteration 423: Loss = 0.000412
# Iteration 424: Loss = 0.000396
# Iteration 425: Loss = 0.000381
# Iteration 426: Loss = 0.000366
# Iteration 427: Loss = 0.000352
# Iteration 428: Loss = 0.000338
# Iteration 429: Loss = 0.000325
# Iteration 430: Loss = 0.000313
# Iteration 431: Loss = 0.000301
# Iteration 432: Loss = 0.000289
# Iteration 433: Loss = 0.000278
# Iteration 434: Loss = 0.000267
# Iteration 435: Loss = 0.000257
# Iteration 436: Loss = 0.000247
# Iteration 437: Loss = 0.000237
# Iteration 438: Loss = 0.000228
# Iteration 439: Loss = 0.000219
# Iteration 440: Loss = 0.000211
# Iteration 441: Loss = 0.000203
# Iteration 442: Loss = 0.000195
# Iteration 443: Loss = 0.000187
# Iteration 444: Loss = 0.000180
# Iteration 445: Loss = 0.000173
# Iteration 446: Loss = 0.000167
# Iteration 447: Loss = 0.000160
# Iteration 448: Loss = 0.000154
# Iteration 449: Loss = 0.000148
# Iteration 450: Loss = 0.000142
# Iteration 451: Loss = 0.000137
# Iteration 452: Loss = 0.000132
# Iteration 453: Loss = 0.000126
# Iteration 454: Loss = 0.000122
# Iteration 455: Loss = 0.000117
# Iteration 456: Loss = 0.000112
# Iteration 457: Loss = 0.000108
# Iteration 458: Loss = 0.000104
# Iteration 459: Loss = 0.000100
# Iteration 460: Loss = 0.000096
# Iteration 461: Loss = 0.000092
# Iteration 462: Loss = 0.000089
# Iteration 463: Loss = 0.000085
# Iteration 464: Loss = 0.000082
# Iteration 465: Loss = 0.000079
# Iteration 466: Loss = 0.000076
# Iteration 467: Loss = 0.000073
# Iteration 468: Loss = 0.000070
# Iteration 469: Loss = 0.000067
# Iteration 470: Loss = 0.000065
# Iteration 471: Loss = 0.000062
# Iteration 472: Loss = 0.000060
# Iteration 473: Loss = 0.000058
# Iteration 474: Loss = 0.000055
# Iteration 475: Loss = 0.000053
# Iteration 476: Loss = 0.000051
# Iteration 477: Loss = 0.000049
# Iteration 478: Loss = 0.000047
# Iteration 479: Loss = 0.000046
# Iteration 480: Loss = 0.000044
# Iteration 481: Loss = 0.000042
# Iteration 482: Loss = 0.000041
# Iteration 483: Loss = 0.000039
# Iteration 484: Loss = 0.000037
# Iteration 485: Loss = 0.000036
# Iteration 486: Loss = 0.000035
# Iteration 487: Loss = 0.000033
# Iteration 488: Loss = 0.000032
# Iteration 489: Loss = 0.000031
# Iteration 490: Loss = 0.000030
# Iteration 491: Loss = 0.000028
# Iteration 492: Loss = 0.000027
# Iteration 493: Loss = 0.000026
# Iteration 494: Loss = 0.000025
# Iteration 495: Loss = 0.000024
# Iteration 496: Loss = 0.000023
# Iteration 497: Loss = 0.000023
# Iteration 498: Loss = 0.000022
# Iteration 499: Loss = 0.000021

# %% [markdown]
# ## PyTorch: Tensors
# Numpy is a great framework, but it cannot utilize GPUs to accelerate its numerical computations. For modern deep neural networks, GPUs often provide speedups of 50x or greater, so unfortunately numpy won't be enough for modern deep learning.
#
# Here we introduce the most fundamental PyTorch concept: the Tensor. A PyTorch Tensor is conceptually identical to a numpy array: a Tensor is an n-dimensional array, and PyTorch provides many functions for operating on these Tensors. Any computation you might want to perform with numpy can also be accomplished with PyTorch Tensors; you should think of them as a generic tool for scientific computing.
#
# However unlike numpy, PyTorch Tensors can utilize GPUs to accelerate their numeric computations. To run a PyTorch Tensor on GPU, you use the device argument when constructing a Tensor to place the Tensor on a GPU.
#
# Here we use PyTorch Tensors to fit a two-layer network to random data. Like the numpy example above we manually implement the forward and backward passes through the network, using operations on PyTorch Tensors:

# %%
# Code in file tensor/two_layer_net_tensor.py
import torch

device = torch.device('cpu')
#device = torch.device('cuda') # Uncomment this to run on GPU
print("device:",device)
# N is batch size; D_in is input dimension;
# H is hidden dimension; D_out is output dimension.
N, D_in, H, D_out = 64, 1000, 100, 10

# Create random input and output data
x = torch.randn(N, D_in, device=device)
y = torch.randn(N, D_out, device=device)

# Randomly initialize weights
w1 = torch.randn(D_in, H, device=device)
w2 = torch.randn(H, D_out, device=device)

learning_rate = 1e-6
for t in range(500):
  # Forward pass: compute predicted y
  h = x.mm(w1)
  h_relu = h.clamp(min=0)
  y_pred = h_relu.mm(w2)

  # Compute and print loss; loss is a scalar, and is stored in a PyTorch Tensor
  # of shape (); we can get its value as a Python number with loss.item().
  loss = (y_pred - y).pow(2).sum()
  print(f"Iteration {t}: Loss = {loss.item():.6f}")

  # Backprop to compute gradients of w1 and w2 with respect to loss
  grad_y_pred = 2.0 * (y_pred - y)
  grad_w2 = h_relu.t().mm(grad_y_pred)
  grad_h_relu = grad_y_pred.mm(w2.t())
  grad_h = grad_h_relu.clone()
  grad_h[h < 0] = 0
  grad_w1 = x.t().mm(grad_h)

  # Update weights using gradient descent
  w1 -= learning_rate * grad_w1
  w2 -= learning_rate * grad_w2
# Out:
# device: cpu
# Iteration 0: Loss = 26638656.000000
# Iteration 1: Loss = 22390720.000000
# Iteration 2: Loss = 21406948.000000
# Iteration 3: Loss = 20782100.000000
# Iteration 4: Loss = 18961674.000000
# Iteration 5: Loss = 15572472.000000
# Iteration 6: Loss = 11473173.000000
# Iteration 7: Loss = 7715688.000000
# Iteration 8: Loss = 4934873.000000
# Iteration 9: Loss = 3121183.000000
# Iteration 10: Loss = 2025165.500000
# Iteration 11: Loss = 1375202.750000
# Iteration 12: Loss = 987179.875000
# Iteration 13: Loss = 746736.062500
# Iteration 14: Loss = 590436.000000
# Iteration 15: Loss = 482895.218750
# Iteration 16: Loss = 404745.000000
# Iteration 17: Loss = 345260.375000
# Iteration 18: Loss = 298363.656250
# Iteration 19: Loss = 260276.218750
# Iteration 20: Loss = 228640.156250
# Iteration 21: Loss = 201981.187500
# Iteration 22: Loss = 179230.234375
# Iteration 23: Loss = 159695.078125
# Iteration 24: Loss = 142748.390625
# Iteration 25: Loss = 127965.875000
# Iteration 26: Loss = 115012.296875
# Iteration 27: Loss = 103623.781250
# Iteration 28: Loss = 93576.453125
# Iteration 29: Loss = 84670.414062
# Iteration 30: Loss = 76764.687500
# Iteration 31: Loss = 69726.203125
# Iteration 32: Loss = 63443.257812
# Iteration 33: Loss = 57819.386719
# Iteration 34: Loss = 52772.230469
# Iteration 35: Loss = 48240.429688
# Iteration 36: Loss = 44157.843750
# Iteration 37: Loss = 40474.750000
# Iteration 38: Loss = 37145.660156
# Iteration 39: Loss = 34136.878906
# Iteration 40: Loss = 31410.285156
# Iteration 41: Loss = 28934.484375
# Iteration 42: Loss = 26681.445312
# Iteration 43: Loss = 24629.304688
# Iteration 44: Loss = 22756.007812
# Iteration 45: Loss = 21045.085938
# Iteration 46: Loss = 19480.292969
# Iteration 47: Loss = 18047.935547
# Iteration 48: Loss = 16734.175781
# Iteration 49: Loss = 15528.622070
# Iteration 50: Loss = 14421.033203
# Iteration 51: Loss = 13402.450195
# Iteration 52: Loss = 12464.487305
# Iteration 53: Loss = 11603.748047
# Iteration 54: Loss = 10809.498047
# Iteration 55: Loss = 10076.285156
# Iteration 56: Loss = 9399.134766
# Iteration 57: Loss = 8772.917969
# Iteration 58: Loss = 8195.025391
# Iteration 59: Loss = 7660.232422
# Iteration 60: Loss = 7164.367188
# Iteration 61: Loss = 6704.287109
# Iteration 62: Loss = 6276.676270
# Iteration 63: Loss = 5879.223145
# Iteration 64: Loss = 5509.572266
# Iteration 65: Loss = 5165.586426
# Iteration 66: Loss = 4845.269531
# Iteration 67: Loss = 4546.697754
# Iteration 68: Loss = 4268.328613
# Iteration 69: Loss = 4008.648682
# Iteration 70: Loss = 3766.403320
# Iteration 71: Loss = 3540.354736
# Iteration 72: Loss = 3329.442627
# Iteration 73: Loss = 3132.183594
# Iteration 74: Loss = 2947.619141
# Iteration 75: Loss = 2774.957764
# Iteration 76: Loss = 2613.237061
# Iteration 77: Loss = 2461.749268
# Iteration 78: Loss = 2319.771240
# Iteration 79: Loss = 2186.712402
# Iteration 80: Loss = 2061.902344
# Iteration 81: Loss = 1944.754761
# Iteration 82: Loss = 1834.841553
# Iteration 83: Loss = 1731.622925
# Iteration 84: Loss = 1634.677124
# Iteration 85: Loss = 1543.633301
# Iteration 86: Loss = 1458.065186
# Iteration 87: Loss = 1377.567627
# Iteration 88: Loss = 1301.864502
# Iteration 89: Loss = 1230.620361
# Iteration 90: Loss = 1163.560669
# Iteration 91: Loss = 1100.412354
# Iteration 92: Loss = 1040.946533
# Iteration 93: Loss = 984.953613
# Iteration 94: Loss = 932.132324
# Iteration 95: Loss = 882.361572
# Iteration 96: Loss = 835.415161
# Iteration 97: Loss = 791.136780
# Iteration 98: Loss = 749.365540
# Iteration 99: Loss = 709.937683
# Iteration 100: Loss = 672.726074
# Iteration 101: Loss = 637.576599
# Iteration 102: Loss = 604.388306
# Iteration 103: Loss = 573.036438
# Iteration 104: Loss = 543.422302
# Iteration 105: Loss = 515.430359
# Iteration 106: Loss = 488.948181
# Iteration 107: Loss = 463.915680
# Iteration 108: Loss = 440.240082
# Iteration 109: Loss = 417.842926
# Iteration 110: Loss = 396.647278
# Iteration 111: Loss = 376.594238
# Iteration 112: Loss = 357.611572
# Iteration 113: Loss = 339.633026
# Iteration 114: Loss = 322.612152
# Iteration 115: Loss = 306.496033
# Iteration 116: Loss = 291.228180
# Iteration 117: Loss = 276.755005
# Iteration 118: Loss = 263.037231
# Iteration 119: Loss = 250.040405
# Iteration 120: Loss = 237.715912
# Iteration 121: Loss = 226.027863
# Iteration 122: Loss = 214.946365
# Iteration 123: Loss = 204.434143
# Iteration 124: Loss = 194.461166
# Iteration 125: Loss = 185.000351
# Iteration 126: Loss = 176.017548
# Iteration 127: Loss = 167.498093
# Iteration 128: Loss = 159.407913
# Iteration 129: Loss = 151.725220
# Iteration 130: Loss = 144.431610
# Iteration 131: Loss = 137.503983
# Iteration 132: Loss = 130.923676
# Iteration 133: Loss = 124.670181
# Iteration 134: Loss = 118.729240
# Iteration 135: Loss = 113.085388
# Iteration 136: Loss = 107.718719
# Iteration 137: Loss = 102.618843
# Iteration 138: Loss = 97.772003
# Iteration 139: Loss = 93.162277
# Iteration 140: Loss = 88.778908
# Iteration 141: Loss = 84.612389
# Iteration 142: Loss = 80.647385
# Iteration 143: Loss = 76.874817
# Iteration 144: Loss = 73.284813
# Iteration 145: Loss = 69.871262
# Iteration 146: Loss = 66.621071
# Iteration 147: Loss = 63.528049
# Iteration 148: Loss = 60.584152
# Iteration 149: Loss = 57.783268
# Iteration 150: Loss = 55.113449
# Iteration 151: Loss = 52.574081
# Iteration 152: Loss = 50.155083
# Iteration 153: Loss = 47.850914
# Iteration 154: Loss = 45.657825
# Iteration 155: Loss = 43.567528
# Iteration 156: Loss = 41.575111
# Iteration 157: Loss = 39.678181
# Iteration 158: Loss = 37.870193
# Iteration 159: Loss = 36.147701
# Iteration 160: Loss = 34.505493
# Iteration 161: Loss = 32.940975
# Iteration 162: Loss = 31.449198
# Iteration 163: Loss = 30.026302
# Iteration 164: Loss = 28.670666
# Iteration 165: Loss = 27.378199
# Iteration 166: Loss = 26.144983
# Iteration 167: Loss = 24.969877
# Iteration 168: Loss = 23.848938
# Iteration 169: Loss = 22.779427
# Iteration 170: Loss = 21.759893
# Iteration 171: Loss = 20.786295
# Iteration 172: Loss = 19.858057
# Iteration 173: Loss = 18.971775
# Iteration 174: Loss = 18.126856
# Iteration 175: Loss = 17.320330
# Iteration 176: Loss = 16.550228
# Iteration 177: Loss = 15.815755
# Iteration 178: Loss = 15.114203
# Iteration 179: Loss = 14.445002
# Iteration 180: Loss = 13.805706
# Iteration 181: Loss = 13.195813
# Iteration 182: Loss = 12.613423
# Iteration 183: Loss = 12.057795
# Iteration 184: Loss = 11.526461
# Iteration 185: Loss = 11.019535
# Iteration 186: Loss = 10.535244
# Iteration 187: Loss = 10.072687
# Iteration 188: Loss = 9.631004
# Iteration 189: Loss = 9.208721
# Iteration 190: Loss = 8.805902
# Iteration 191: Loss = 8.420899
# Iteration 192: Loss = 8.052811
# Iteration 193: Loss = 7.701425
# Iteration 194: Loss = 7.365967
# Iteration 195: Loss = 7.044865
# Iteration 196: Loss = 6.738072
# Iteration 197: Loss = 6.445150
# Iteration 198: Loss = 6.165206
# Iteration 199: Loss = 5.897460
# Iteration 200: Loss = 5.641770
# Iteration 201: Loss = 5.397456
# Iteration 202: Loss = 5.163585
# Iteration 203: Loss = 4.940187
# Iteration 204: Loss = 4.726721
# Iteration 205: Loss = 4.522562
# Iteration 206: Loss = 4.327361
# Iteration 207: Loss = 4.140953
# Iteration 208: Loss = 3.962401
# Iteration 209: Loss = 3.791578
# Iteration 210: Loss = 3.628487
# Iteration 211: Loss = 3.472486
# Iteration 212: Loss = 3.323407
# Iteration 213: Loss = 3.180580
# Iteration 214: Loss = 3.044093
# Iteration 215: Loss = 2.913621
# Iteration 216: Loss = 2.788731
# Iteration 217: Loss = 2.669397
# Iteration 218: Loss = 2.555271
# Iteration 219: Loss = 2.445929
# Iteration 220: Loss = 2.341391
# Iteration 221: Loss = 2.241319
# Iteration 222: Loss = 2.145682
# Iteration 223: Loss = 2.054171
# Iteration 224: Loss = 1.966665
# Iteration 225: Loss = 1.882757
# Iteration 226: Loss = 1.802542
# Iteration 227: Loss = 1.725918
# Iteration 228: Loss = 1.652507
# Iteration 229: Loss = 1.582150
# Iteration 230: Loss = 1.514904
# Iteration 231: Loss = 1.450648
# Iteration 232: Loss = 1.388977
# Iteration 233: Loss = 1.330138
# Iteration 234: Loss = 1.273832
# Iteration 235: Loss = 1.219743
# Iteration 236: Loss = 1.168108
# Iteration 237: Loss = 1.118780
# Iteration 238: Loss = 1.071316
# Iteration 239: Loss = 1.025985
# Iteration 240: Loss = 0.982687
# Iteration 241: Loss = 0.941120
# Iteration 242: Loss = 0.901380
# Iteration 243: Loss = 0.863317
# Iteration 244: Loss = 0.826861
# Iteration 245: Loss = 0.791983
# Iteration 246: Loss = 0.758652
# Iteration 247: Loss = 0.726628
# Iteration 248: Loss = 0.696056
# Iteration 249: Loss = 0.666736
# Iteration 250: Loss = 0.638712
# Iteration 251: Loss = 0.611839
# Iteration 252: Loss = 0.586104
# Iteration 253: Loss = 0.561509
# Iteration 254: Loss = 0.537888
# Iteration 255: Loss = 0.515355
# Iteration 256: Loss = 0.493595
# Iteration 257: Loss = 0.472851
# Iteration 258: Loss = 0.453029
# Iteration 259: Loss = 0.434049
# Iteration 260: Loss = 0.415784
# Iteration 261: Loss = 0.398438
# Iteration 262: Loss = 0.381725
# Iteration 263: Loss = 0.365666
# Iteration 264: Loss = 0.350364
# Iteration 265: Loss = 0.335749
# Iteration 266: Loss = 0.321742
# Iteration 267: Loss = 0.308290
# Iteration 268: Loss = 0.295354
# Iteration 269: Loss = 0.282954
# Iteration 270: Loss = 0.271181
# Iteration 271: Loss = 0.259887
# Iteration 272: Loss = 0.248996
# Iteration 273: Loss = 0.238632
# Iteration 274: Loss = 0.228626
# Iteration 275: Loss = 0.219121
# Iteration 276: Loss = 0.209938
# Iteration 277: Loss = 0.201209
# Iteration 278: Loss = 0.192809
# Iteration 279: Loss = 0.184788
# Iteration 280: Loss = 0.177107
# Iteration 281: Loss = 0.169708
# Iteration 282: Loss = 0.162606
# Iteration 283: Loss = 0.155857
# Iteration 284: Loss = 0.149381
# Iteration 285: Loss = 0.143160
# Iteration 286: Loss = 0.137175
# Iteration 287: Loss = 0.131480
# Iteration 288: Loss = 0.126017
# Iteration 289: Loss = 0.120773
# Iteration 290: Loss = 0.115753
# Iteration 291: Loss = 0.110965
# Iteration 292: Loss = 0.106370
# Iteration 293: Loss = 0.101958
# Iteration 294: Loss = 0.097735
# Iteration 295: Loss = 0.093675
# Iteration 296: Loss = 0.089781
# Iteration 297: Loss = 0.086062
# Iteration 298: Loss = 0.082467
# Iteration 299: Loss = 0.079040
# Iteration 300: Loss = 0.075776
# Iteration 301: Loss = 0.072654
# Iteration 302: Loss = 0.069648
# Iteration 303: Loss = 0.066764
# Iteration 304: Loss = 0.063969
# Iteration 305: Loss = 0.061331
# Iteration 306: Loss = 0.058787
# Iteration 307: Loss = 0.056373
# Iteration 308: Loss = 0.054034
# Iteration 309: Loss = 0.051788
# Iteration 310: Loss = 0.049649
# Iteration 311: Loss = 0.047598
# Iteration 312: Loss = 0.045651
# Iteration 313: Loss = 0.043755
# Iteration 314: Loss = 0.041970
# Iteration 315: Loss = 0.040247
# Iteration 316: Loss = 0.038585
# Iteration 317: Loss = 0.036996
# Iteration 318: Loss = 0.035471
# Iteration 319: Loss = 0.034010
# Iteration 320: Loss = 0.032603
# Iteration 321: Loss = 0.031268
# Iteration 322: Loss = 0.029998
# Iteration 323: Loss = 0.028758
# Iteration 324: Loss = 0.027578
# Iteration 325: Loss = 0.026455
# Iteration 326: Loss = 0.025370
# Iteration 327: Loss = 0.024335
# Iteration 328: Loss = 0.023336
# Iteration 329: Loss = 0.022386
# Iteration 330: Loss = 0.021465
# Iteration 331: Loss = 0.020594
# Iteration 332: Loss = 0.019748
# Iteration 333: Loss = 0.018942
# Iteration 334: Loss = 0.018165
# Iteration 335: Loss = 0.017432
# Iteration 336: Loss = 0.016722
# Iteration 337: Loss = 0.016043
# Iteration 338: Loss = 0.015401
# Iteration 339: Loss = 0.014773
# Iteration 340: Loss = 0.014178
# Iteration 341: Loss = 0.013609
# Iteration 342: Loss = 0.013059
# Iteration 343: Loss = 0.012522
# Iteration 344: Loss = 0.012019
# Iteration 345: Loss = 0.011537
# Iteration 346: Loss = 0.011076
# Iteration 347: Loss = 0.010630
# Iteration 348: Loss = 0.010204
# Iteration 349: Loss = 0.009799
# Iteration 350: Loss = 0.009405
# Iteration 351: Loss = 0.009029
# Iteration 352: Loss = 0.008671
# Iteration 353: Loss = 0.008326
# Iteration 354: Loss = 0.007998
# Iteration 355: Loss = 0.007684
# Iteration 356: Loss = 0.007379
# Iteration 357: Loss = 0.007089
# Iteration 358: Loss = 0.006812
# Iteration 359: Loss = 0.006541
# Iteration 360: Loss = 0.006286
# Iteration 361: Loss = 0.006039
# Iteration 362: Loss = 0.005804
# Iteration 363: Loss = 0.005581
# Iteration 364: Loss = 0.005365
# Iteration 365: Loss = 0.005154
# Iteration 366: Loss = 0.004959
# Iteration 367: Loss = 0.004767
# Iteration 368: Loss = 0.004586
# Iteration 369: Loss = 0.004411
# Iteration 370: Loss = 0.004245
# Iteration 371: Loss = 0.004085
# Iteration 372: Loss = 0.003932
# Iteration 373: Loss = 0.003783
# Iteration 374: Loss = 0.003642
# Iteration 375: Loss = 0.003504
# Iteration 376: Loss = 0.003374
# Iteration 377: Loss = 0.003250
# Iteration 378: Loss = 0.003129
# Iteration 379: Loss = 0.003014
# Iteration 380: Loss = 0.002905
# Iteration 381: Loss = 0.002800
# Iteration 382: Loss = 0.002700
# Iteration 383: Loss = 0.002603
# Iteration 384: Loss = 0.002508
# Iteration 385: Loss = 0.002417
# Iteration 386: Loss = 0.002331
# Iteration 387: Loss = 0.002247
# Iteration 388: Loss = 0.002169
# Iteration 389: Loss = 0.002093
# Iteration 390: Loss = 0.002021
# Iteration 391: Loss = 0.001950
# Iteration 392: Loss = 0.001881
# Iteration 393: Loss = 0.001819
# Iteration 394: Loss = 0.001756
# Iteration 395: Loss = 0.001696
# Iteration 396: Loss = 0.001639
# Iteration 397: Loss = 0.001586
# Iteration 398: Loss = 0.001530
# Iteration 399: Loss = 0.001481
# Iteration 400: Loss = 0.001431
# Iteration 401: Loss = 0.001385
# Iteration 402: Loss = 0.001340
# Iteration 403: Loss = 0.001299
# Iteration 404: Loss = 0.001256
# Iteration 405: Loss = 0.001216
# Iteration 406: Loss = 0.001176
# Iteration 407: Loss = 0.001140
# Iteration 408: Loss = 0.001102
# Iteration 409: Loss = 0.001067
# Iteration 410: Loss = 0.001035
# Iteration 411: Loss = 0.001002
# Iteration 412: Loss = 0.000971
# Iteration 413: Loss = 0.000942
# Iteration 414: Loss = 0.000915
# Iteration 415: Loss = 0.000887
# Iteration 416: Loss = 0.000860
# Iteration 417: Loss = 0.000834
# Iteration 418: Loss = 0.000808
# Iteration 419: Loss = 0.000784
# Iteration 420: Loss = 0.000760
# Iteration 421: Loss = 0.000741
# Iteration 422: Loss = 0.000719
# Iteration 423: Loss = 0.000697
# Iteration 424: Loss = 0.000677
# Iteration 425: Loss = 0.000658
# Iteration 426: Loss = 0.000641
# Iteration 427: Loss = 0.000623
# Iteration 428: Loss = 0.000605
# Iteration 429: Loss = 0.000588
# Iteration 430: Loss = 0.000572
# Iteration 431: Loss = 0.000557
# Iteration 432: Loss = 0.000542
# Iteration 433: Loss = 0.000528
# Iteration 434: Loss = 0.000513
# Iteration 435: Loss = 0.000500
# Iteration 436: Loss = 0.000485
# Iteration 437: Loss = 0.000473
# Iteration 438: Loss = 0.000461
# Iteration 439: Loss = 0.000449
# Iteration 440: Loss = 0.000438
# Iteration 441: Loss = 0.000427
# Iteration 442: Loss = 0.000416
# Iteration 443: Loss = 0.000406
# Iteration 444: Loss = 0.000396
# Iteration 445: Loss = 0.000387
# Iteration 446: Loss = 0.000378
# Iteration 447: Loss = 0.000368
# Iteration 448: Loss = 0.000359
# Iteration 449: Loss = 0.000350
# Iteration 450: Loss = 0.000342
# Iteration 451: Loss = 0.000335
# Iteration 452: Loss = 0.000327
# Iteration 453: Loss = 0.000318
# Iteration 454: Loss = 0.000311
# Iteration 455: Loss = 0.000304
# Iteration 456: Loss = 0.000297
# Iteration 457: Loss = 0.000290
# Iteration 458: Loss = 0.000284
# Iteration 459: Loss = 0.000277
# Iteration 460: Loss = 0.000271
# Iteration 461: Loss = 0.000265
# Iteration 462: Loss = 0.000259
# Iteration 463: Loss = 0.000254
# Iteration 464: Loss = 0.000248
# Iteration 465: Loss = 0.000243
# Iteration 466: Loss = 0.000237
# Iteration 467: Loss = 0.000232
# Iteration 468: Loss = 0.000227
# Iteration 469: Loss = 0.000222
# Iteration 470: Loss = 0.000218
# Iteration 471: Loss = 0.000213
# Iteration 472: Loss = 0.000208
# Iteration 473: Loss = 0.000204
# Iteration 474: Loss = 0.000200
# Iteration 475: Loss = 0.000196
# Iteration 476: Loss = 0.000193
# Iteration 477: Loss = 0.000189
# Iteration 478: Loss = 0.000185
# Iteration 479: Loss = 0.000181
# Iteration 480: Loss = 0.000178
# Iteration 481: Loss = 0.000174
# Iteration 482: Loss = 0.000171
# Iteration 483: Loss = 0.000168
# Iteration 484: Loss = 0.000165
# Iteration 485: Loss = 0.000162
# Iteration 486: Loss = 0.000159
# Iteration 487: Loss = 0.000156
# Iteration 488: Loss = 0.000153
# Iteration 489: Loss = 0.000150
# Iteration 490: Loss = 0.000147
# Iteration 491: Loss = 0.000145
# Iteration 492: Loss = 0.000143
# Iteration 493: Loss = 0.000140
# Iteration 494: Loss = 0.000137
# Iteration 495: Loss = 0.000135
# Iteration 496: Loss = 0.000133
# Iteration 497: Loss = 0.000130
# Iteration 498: Loss = 0.000128
# Iteration 499: Loss = 0.000125

# %% [markdown]
# ##PyTorch: Autograd
#
# In the above examples, we had to manually implement both the forward and backward passes of our neural network. Manually implementing the backward pass is not a big deal for a small two-layer network, but can quickly get very hairy for large complex networks.
#
# Thankfully, we can use automatic differentiation to automate the computation of backward passes in neural networks. The autograd package in PyTorch provides exactly this functionality. When using autograd, the forward pass of your network will define a computational graph; nodes in the graph will be Tensors, and edges will be functions that produce output Tensors from input Tensors. Backpropagating through this graph then allows you to easily compute gradients.
#
# This sounds complicated, it's pretty simple to use in practice. If we want to compute gradients with respect to some Tensor, then we set requires_grad=True when constructing that Tensor. Any PyTorch operations on that Tensor will cause a computational graph to be constructed, allowing us to later perform backpropagation through the graph. If x is a Tensor with requires_grad=True, then after backpropagation x.grad will be another Tensor holding the gradient of x with respect to some scalar value.
#
# Sometimes you may wish to prevent PyTorch from building computational graphs when performing certain operations on Tensors with requires_grad=True; for example we usually don't want to backpropagate through the weight update steps when training a neural network. In such scenarios we can use the torch.no_grad() context manager to prevent the construction of a computational graph.
#
# Here we use PyTorch Tensors and autograd to implement our two-layer network; now we no longer need to manually implement the backward pass through the network:

# %%
# Code in file autograd/two_layer_net_autograd.py
import torch

device = torch.device('cpu')
# device = torch.device('cuda') # Uncomment this to run on GPU

# N is batch size; D_in is input dimension;
# H is hidden dimension; D_out is output dimension.
N, D_in, H, D_out = 64, 1000, 100, 10

# Create random Tensors to hold input and outputs
x = torch.randn(N, D_in, device=device)
y = torch.randn(N, D_out, device=device)

# Create random Tensors for weights; setting requires_grad=True means that we
# want to compute gradients for these Tensors during the backward pass.
w1 = torch.randn(D_in, H, device=device, requires_grad=True)
w2 = torch.randn(H, D_out, device=device, requires_grad=True)

learning_rate = 1e-6
for t in range(500):
  # Forward pass: compute predicted y using operations on Tensors. Since w1 and
  # w2 have requires_grad=True, operations involving these Tensors will cause
  # PyTorch to build a computational graph, allowing automatic computation of
  # gradients. Since we are no longer implementing the backward pass by hand we
  # don't need to keep references to intermediate values.
  y_pred = x.mm(w1).clamp(min=0).mm(w2)

  # Compute and print loss. Loss is a Tensor of shape (), and loss.item()
  # is a Python number giving its value.
  loss = (y_pred - y).pow(2).sum()
  print(f"Iteration {t}: Loss = {loss.item():.6f}")

  # Use autograd to compute the backward pass. This call will compute the
  # gradient of loss with respect to all Tensors with requires_grad=True.
  # After this call w1.grad and w2.grad will be Tensors holding the gradient
  # of the loss with respect to w1 and w2 respectively.
  loss.backward()

  # Update weights using gradient descent. For this step we just want to mutate
  # the values of w1 and w2 in-place; we don't want to build up a computational
  # graph for the update steps, so we use the torch.no_grad() context manager
  # to prevent PyTorch from building a computational graph for the updates
  with torch.no_grad():
    w1 -= learning_rate * w1.grad
    w2 -= learning_rate * w2.grad

    # Manually zero the gradients after running the backward pass
    w1.grad.zero_()
    w2.grad.zero_()
# Out:
# Iteration 0: Loss = 28609870.000000
# Iteration 1: Loss = 24658280.000000
# Iteration 2: Loss = 24529634.000000
# Iteration 3: Loss = 24502900.000000
# Iteration 4: Loss = 22552322.000000
# Iteration 5: Loss = 17924538.000000
# Iteration 6: Loss = 12406175.000000
# Iteration 7: Loss = 7668046.000000
# Iteration 8: Loss = 4543764.500000
# Iteration 9: Loss = 2725073.250000
# Iteration 10: Loss = 1734911.875000
# Iteration 11: Loss = 1188862.500000
# Iteration 12: Loss = 875106.187500
# Iteration 13: Loss = 681594.437500
# Iteration 14: Loss = 552340.687500
# Iteration 15: Loss = 459709.781250
# Iteration 16: Loss = 389477.625000
# Iteration 17: Loss = 333957.187500
# Iteration 18: Loss = 288806.562500
# Iteration 19: Loss = 251364.640625
# Iteration 20: Loss = 219865.656250
# Iteration 21: Loss = 193105.000000
# Iteration 22: Loss = 170204.984375
# Iteration 23: Loss = 150516.312500
# Iteration 24: Loss = 133471.218750
# Iteration 25: Loss = 118661.015625
# Iteration 26: Loss = 105767.703125
# Iteration 27: Loss = 94510.414062
# Iteration 28: Loss = 84630.109375
# Iteration 29: Loss = 75936.414062
# Iteration 30: Loss = 68268.695312
# Iteration 31: Loss = 61486.832031
# Iteration 32: Loss = 55479.742188
# Iteration 33: Loss = 50144.867188
# Iteration 34: Loss = 45397.679688
# Iteration 35: Loss = 41163.507812
# Iteration 36: Loss = 37380.777344
# Iteration 37: Loss = 33997.726562
# Iteration 38: Loss = 30961.890625
# Iteration 39: Loss = 28236.119141
# Iteration 40: Loss = 25785.427734
# Iteration 41: Loss = 23575.453125
# Iteration 42: Loss = 21580.664062
# Iteration 43: Loss = 19776.380859
# Iteration 44: Loss = 18143.640625
# Iteration 45: Loss = 16663.255859
# Iteration 46: Loss = 15319.654297
# Iteration 47: Loss = 14097.466797
# Iteration 48: Loss = 12984.695312
# Iteration 49: Loss = 11970.083984
# Iteration 50: Loss = 11043.743164
# Iteration 51: Loss = 10197.550781
# Iteration 52: Loss = 9425.045898
# Iteration 53: Loss = 8717.758789
# Iteration 54: Loss = 8070.871094
# Iteration 55: Loss = 7477.615234
# Iteration 56: Loss = 6932.467773
# Iteration 57: Loss = 6431.277344
# Iteration 58: Loss = 5970.006836
# Iteration 59: Loss = 5545.349609
# Iteration 60: Loss = 5153.795410
# Iteration 61: Loss = 4792.811035
# Iteration 62: Loss = 4459.354492
# Iteration 63: Loss = 4151.283203
# Iteration 64: Loss = 3866.432373
# Iteration 65: Loss = 3602.940430
# Iteration 66: Loss = 3358.913818
# Iteration 67: Loss = 3132.867676
# Iteration 68: Loss = 2923.290527
# Iteration 69: Loss = 2728.937744
# Iteration 70: Loss = 2548.627686
# Iteration 71: Loss = 2381.073486
# Iteration 72: Loss = 2225.423096
# Iteration 73: Loss = 2080.672852
# Iteration 74: Loss = 1946.062256
# Iteration 75: Loss = 1820.886963
# Iteration 76: Loss = 1704.270020
# Iteration 77: Loss = 1595.625977
# Iteration 78: Loss = 1494.384277
# Iteration 79: Loss = 1399.996338
# Iteration 80: Loss = 1311.996704
# Iteration 81: Loss = 1229.852051
# Iteration 82: Loss = 1153.187500
# Iteration 83: Loss = 1081.603516
# Iteration 84: Loss = 1014.735840
# Iteration 85: Loss = 952.252075
# Iteration 86: Loss = 893.829163
# Iteration 87: Loss = 839.197021
# Iteration 88: Loss = 788.105957
# Iteration 89: Loss = 740.295044
# Iteration 90: Loss = 695.523376
# Iteration 91: Loss = 653.609985
# Iteration 92: Loss = 614.336670
# Iteration 93: Loss = 577.549133
# Iteration 94: Loss = 543.070679
# Iteration 95: Loss = 510.755676
# Iteration 96: Loss = 480.463684
# Iteration 97: Loss = 452.114746
# Iteration 98: Loss = 425.532227
# Iteration 99: Loss = 400.587219
# Iteration 100: Loss = 377.171997
# Iteration 101: Loss = 355.204071
# Iteration 102: Loss = 334.559998
# Iteration 103: Loss = 315.168762
# Iteration 104: Loss = 296.942871
# Iteration 105: Loss = 279.817139
# Iteration 106: Loss = 263.722626
# Iteration 107: Loss = 248.588470
# Iteration 108: Loss = 234.353195
# Iteration 109: Loss = 220.972672
# Iteration 110: Loss = 208.377747
# Iteration 111: Loss = 196.529587
# Iteration 112: Loss = 185.378540
# Iteration 113: Loss = 174.890808
# Iteration 114: Loss = 165.009338
# Iteration 115: Loss = 155.709702
# Iteration 116: Loss = 146.946930
# Iteration 117: Loss = 138.695709
# Iteration 118: Loss = 130.923218
# Iteration 119: Loss = 123.599915
# Iteration 120: Loss = 116.698425
# Iteration 121: Loss = 110.193741
# Iteration 122: Loss = 104.067459
# Iteration 123: Loss = 98.289452
# Iteration 124: Loss = 92.842987
# Iteration 125: Loss = 87.707886
# Iteration 126: Loss = 82.862869
# Iteration 127: Loss = 78.294167
# Iteration 128: Loss = 73.987762
# Iteration 129: Loss = 69.945633
# Iteration 130: Loss = 66.130486
# Iteration 131: Loss = 62.530941
# Iteration 132: Loss = 59.131699
# Iteration 133: Loss = 55.922150
# Iteration 134: Loss = 52.892239
# Iteration 135: Loss = 50.032200
# Iteration 136: Loss = 47.332104
# Iteration 137: Loss = 44.778309
# Iteration 138: Loss = 42.367287
# Iteration 139: Loss = 40.089020
# Iteration 140: Loss = 37.936871
# Iteration 141: Loss = 35.903641
# Iteration 142: Loss = 33.981373
# Iteration 143: Loss = 32.163830
# Iteration 144: Loss = 30.447508
# Iteration 145: Loss = 28.824341
# Iteration 146: Loss = 27.290361
# Iteration 147: Loss = 25.840059
# Iteration 148: Loss = 24.468086
# Iteration 149: Loss = 23.169594
# Iteration 150: Loss = 21.942402
# Iteration 151: Loss = 20.781609
# Iteration 152: Loss = 19.683439
# Iteration 153: Loss = 18.644857
# Iteration 154: Loss = 17.661659
# Iteration 155: Loss = 16.731607
# Iteration 156: Loss = 15.851889
# Iteration 157: Loss = 15.019461
# Iteration 158: Loss = 14.231581
# Iteration 159: Loss = 13.485550
# Iteration 160: Loss = 12.779482
# Iteration 161: Loss = 12.111131
# Iteration 162: Loss = 11.478489
# Iteration 163: Loss = 10.879736
# Iteration 164: Loss = 10.312547
# Iteration 165: Loss = 9.775771
# Iteration 166: Loss = 9.267291
# Iteration 167: Loss = 8.785720
# Iteration 168: Loss = 8.329866
# Iteration 169: Loss = 7.897893
# Iteration 170: Loss = 7.488477
# Iteration 171: Loss = 7.100995
# Iteration 172: Loss = 6.733401
# Iteration 173: Loss = 6.386183
# Iteration 174: Loss = 6.056354
# Iteration 175: Loss = 5.744395
# Iteration 176: Loss = 5.448564
# Iteration 177: Loss = 5.167821
# Iteration 178: Loss = 4.902338
# Iteration 179: Loss = 4.650569
# Iteration 180: Loss = 4.412145
# Iteration 181: Loss = 4.185981
# Iteration 182: Loss = 3.971222
# Iteration 183: Loss = 3.768126
# Iteration 184: Loss = 3.575101
# Iteration 185: Loss = 3.392572
# Iteration 186: Loss = 3.219813
# Iteration 187: Loss = 3.055431
# Iteration 188: Loss = 2.899751
# Iteration 189: Loss = 2.752069
# Iteration 190: Loss = 2.611888
# Iteration 191: Loss = 2.479089
# Iteration 192: Loss = 2.353083
# Iteration 193: Loss = 2.233760
# Iteration 194: Loss = 2.120421
# Iteration 195: Loss = 2.012904
# Iteration 196: Loss = 1.911227
# Iteration 197: Loss = 1.814462
# Iteration 198: Loss = 1.722563
# Iteration 199: Loss = 1.635672
# Iteration 200: Loss = 1.552896
# Iteration 201: Loss = 1.474674
# Iteration 202: Loss = 1.400435
# Iteration 203: Loss = 1.329699
# Iteration 204: Loss = 1.262941
# Iteration 205: Loss = 1.199553
# Iteration 206: Loss = 1.139128
# Iteration 207: Loss = 1.081980
# Iteration 208: Loss = 1.027664
# Iteration 209: Loss = 0.976091
# Iteration 210: Loss = 0.927108
# Iteration 211: Loss = 0.880702
# Iteration 212: Loss = 0.836550
# Iteration 213: Loss = 0.794614
# Iteration 214: Loss = 0.755079
# Iteration 215: Loss = 0.717435
# Iteration 216: Loss = 0.681584
# Iteration 217: Loss = 0.647522
# Iteration 218: Loss = 0.615354
# Iteration 219: Loss = 0.584656
# Iteration 220: Loss = 0.555463
# Iteration 221: Loss = 0.527855
# Iteration 222: Loss = 0.501634
# Iteration 223: Loss = 0.476693
# Iteration 224: Loss = 0.453080
# Iteration 225: Loss = 0.430626
# Iteration 226: Loss = 0.409261
# Iteration 227: Loss = 0.388883
# Iteration 228: Loss = 0.369637
# Iteration 229: Loss = 0.351374
# Iteration 230: Loss = 0.333957
# Iteration 231: Loss = 0.317401
# Iteration 232: Loss = 0.301792
# Iteration 233: Loss = 0.286932
# Iteration 234: Loss = 0.272750
# Iteration 235: Loss = 0.259282
# Iteration 236: Loss = 0.246484
# Iteration 237: Loss = 0.234308
# Iteration 238: Loss = 0.222734
# Iteration 239: Loss = 0.211795
# Iteration 240: Loss = 0.201376
# Iteration 241: Loss = 0.191490
# Iteration 242: Loss = 0.182096
# Iteration 243: Loss = 0.173140
# Iteration 244: Loss = 0.164627
# Iteration 245: Loss = 0.156563
# Iteration 246: Loss = 0.148855
# Iteration 247: Loss = 0.141551
# Iteration 248: Loss = 0.134630
# Iteration 249: Loss = 0.128052
# Iteration 250: Loss = 0.121790
# Iteration 251: Loss = 0.115826
# Iteration 252: Loss = 0.110202
# Iteration 253: Loss = 0.104791
# Iteration 254: Loss = 0.099665
# Iteration 255: Loss = 0.094782
# Iteration 256: Loss = 0.090192
# Iteration 257: Loss = 0.085808
# Iteration 258: Loss = 0.081633
# Iteration 259: Loss = 0.077655
# Iteration 260: Loss = 0.073875
# Iteration 261: Loss = 0.070269
# Iteration 262: Loss = 0.066847
# Iteration 263: Loss = 0.063615
# Iteration 264: Loss = 0.060511
# Iteration 265: Loss = 0.057573
# Iteration 266: Loss = 0.054770
# Iteration 267: Loss = 0.052129
# Iteration 268: Loss = 0.049615
# Iteration 269: Loss = 0.047201
# Iteration 270: Loss = 0.044900
# Iteration 271: Loss = 0.042764
# Iteration 272: Loss = 0.040684
# Iteration 273: Loss = 0.038731
# Iteration 274: Loss = 0.036873
# Iteration 275: Loss = 0.035092
# Iteration 276: Loss = 0.033388
# Iteration 277: Loss = 0.031785
# Iteration 278: Loss = 0.030269
# Iteration 279: Loss = 0.028805
# Iteration 280: Loss = 0.027413
# Iteration 281: Loss = 0.026101
# Iteration 282: Loss = 0.024853
# Iteration 283: Loss = 0.023667
# Iteration 284: Loss = 0.022531
# Iteration 285: Loss = 0.021458
# Iteration 286: Loss = 0.020442
# Iteration 287: Loss = 0.019457
# Iteration 288: Loss = 0.018540
# Iteration 289: Loss = 0.017649
# Iteration 290: Loss = 0.016821
# Iteration 291: Loss = 0.016012
# Iteration 292: Loss = 0.015248
# Iteration 293: Loss = 0.014540
# Iteration 294: Loss = 0.013850
# Iteration 295: Loss = 0.013194
# Iteration 296: Loss = 0.012576
# Iteration 297: Loss = 0.011973
# Iteration 298: Loss = 0.011416
# Iteration 299: Loss = 0.010883
# Iteration 300: Loss = 0.010365
# Iteration 301: Loss = 0.009881
# Iteration 302: Loss = 0.009428
# Iteration 303: Loss = 0.008989
# Iteration 304: Loss = 0.008572
# Iteration 305: Loss = 0.008177
# Iteration 306: Loss = 0.007800
# Iteration 307: Loss = 0.007442
# Iteration 308: Loss = 0.007102
# Iteration 309: Loss = 0.006771
# Iteration 310: Loss = 0.006463
# Iteration 311: Loss = 0.006165
# Iteration 312: Loss = 0.005886
# Iteration 313: Loss = 0.005616
# Iteration 314: Loss = 0.005361
# Iteration 315: Loss = 0.005120
# Iteration 316: Loss = 0.004890
# Iteration 317: Loss = 0.004677
# Iteration 318: Loss = 0.004468
# Iteration 319: Loss = 0.004274
# Iteration 320: Loss = 0.004088
# Iteration 321: Loss = 0.003906
# Iteration 322: Loss = 0.003737
# Iteration 323: Loss = 0.003574
# Iteration 324: Loss = 0.003418
# Iteration 325: Loss = 0.003265
# Iteration 326: Loss = 0.003125
# Iteration 327: Loss = 0.002990
# Iteration 328: Loss = 0.002862
# Iteration 329: Loss = 0.002743
# Iteration 330: Loss = 0.002624
# Iteration 331: Loss = 0.002513
# Iteration 332: Loss = 0.002407
# Iteration 333: Loss = 0.002308
# Iteration 334: Loss = 0.002212
# Iteration 335: Loss = 0.002118
# Iteration 336: Loss = 0.002032
# Iteration 337: Loss = 0.001948
# Iteration 338: Loss = 0.001871
# Iteration 339: Loss = 0.001794
# Iteration 340: Loss = 0.001721
# Iteration 341: Loss = 0.001652
# Iteration 342: Loss = 0.001589
# Iteration 343: Loss = 0.001527
# Iteration 344: Loss = 0.001464
# Iteration 345: Loss = 0.001409
# Iteration 346: Loss = 0.001354
# Iteration 347: Loss = 0.001301
# Iteration 348: Loss = 0.001253
# Iteration 349: Loss = 0.001204
# Iteration 350: Loss = 0.001159
# Iteration 351: Loss = 0.001114
# Iteration 352: Loss = 0.001074
# Iteration 353: Loss = 0.001035
# Iteration 354: Loss = 0.000997
# Iteration 355: Loss = 0.000960
# Iteration 356: Loss = 0.000925
# Iteration 357: Loss = 0.000892
# Iteration 358: Loss = 0.000861
# Iteration 359: Loss = 0.000829
# Iteration 360: Loss = 0.000800
# Iteration 361: Loss = 0.000772
# Iteration 362: Loss = 0.000746
# Iteration 363: Loss = 0.000719
# Iteration 364: Loss = 0.000695
# Iteration 365: Loss = 0.000672
# Iteration 366: Loss = 0.000649
# Iteration 367: Loss = 0.000627
# Iteration 368: Loss = 0.000607
# Iteration 369: Loss = 0.000587
# Iteration 370: Loss = 0.000568
# Iteration 371: Loss = 0.000550
# Iteration 372: Loss = 0.000531
# Iteration 373: Loss = 0.000515
# Iteration 374: Loss = 0.000497
# Iteration 375: Loss = 0.000483
# Iteration 376: Loss = 0.000468
# Iteration 377: Loss = 0.000454
# Iteration 378: Loss = 0.000440
# Iteration 379: Loss = 0.000428
# Iteration 380: Loss = 0.000414
# Iteration 381: Loss = 0.000402
# Iteration 382: Loss = 0.000391
# Iteration 383: Loss = 0.000380
# Iteration 384: Loss = 0.000369
# Iteration 385: Loss = 0.000358
# Iteration 386: Loss = 0.000347
# Iteration 387: Loss = 0.000338
# Iteration 388: Loss = 0.000329
# Iteration 389: Loss = 0.000319
# Iteration 390: Loss = 0.000310
# Iteration 391: Loss = 0.000302
# Iteration 392: Loss = 0.000294
# Iteration 393: Loss = 0.000286
# Iteration 394: Loss = 0.000278
# Iteration 395: Loss = 0.000271
# Iteration 396: Loss = 0.000264
# Iteration 397: Loss = 0.000258
# Iteration 398: Loss = 0.000250
# Iteration 399: Loss = 0.000244
# Iteration 400: Loss = 0.000238
# Iteration 401: Loss = 0.000232
# Iteration 402: Loss = 0.000227
# Iteration 403: Loss = 0.000221
# Iteration 404: Loss = 0.000216
# Iteration 405: Loss = 0.000211
# Iteration 406: Loss = 0.000205
# Iteration 407: Loss = 0.000200
# Iteration 408: Loss = 0.000196
# Iteration 409: Loss = 0.000191
# Iteration 410: Loss = 0.000186
# Iteration 411: Loss = 0.000182
# Iteration 412: Loss = 0.000178
# Iteration 413: Loss = 0.000174
# Iteration 414: Loss = 0.000171
# Iteration 415: Loss = 0.000167
# Iteration 416: Loss = 0.000163
# Iteration 417: Loss = 0.000159
# Iteration 418: Loss = 0.000156
# Iteration 419: Loss = 0.000153
# Iteration 420: Loss = 0.000149
# Iteration 421: Loss = 0.000146
# Iteration 422: Loss = 0.000143
# Iteration 423: Loss = 0.000140
# Iteration 424: Loss = 0.000137
# Iteration 425: Loss = 0.000135
# Iteration 426: Loss = 0.000132
# Iteration 427: Loss = 0.000130
# Iteration 428: Loss = 0.000126
# Iteration 429: Loss = 0.000124
# Iteration 430: Loss = 0.000122
# Iteration 431: Loss = 0.000120
# Iteration 432: Loss = 0.000117
# Iteration 433: Loss = 0.000114
# Iteration 434: Loss = 0.000112
# Iteration 435: Loss = 0.000110
# Iteration 436: Loss = 0.000108
# Iteration 437: Loss = 0.000106
# Iteration 438: Loss = 0.000104
# Iteration 439: Loss = 0.000102
# Iteration 440: Loss = 0.000100
# Iteration 441: Loss = 0.000098
# Iteration 442: Loss = 0.000097
# Iteration 443: Loss = 0.000095
# Iteration 444: Loss = 0.000093
# Iteration 445: Loss = 0.000092
# Iteration 446: Loss = 0.000090
# Iteration 447: Loss = 0.000088
# Iteration 448: Loss = 0.000087
# Iteration 449: Loss = 0.000085
# Iteration 450: Loss = 0.000084
# Iteration 451: Loss = 0.000082
# Iteration 452: Loss = 0.000081
# Iteration 453: Loss = 0.000080
# Iteration 454: Loss = 0.000079
# Iteration 455: Loss = 0.000078
# Iteration 456: Loss = 0.000076
# Iteration 457: Loss = 0.000075
# Iteration 458: Loss = 0.000074
# Iteration 459: Loss = 0.000073
# Iteration 460: Loss = 0.000071
# Iteration 461: Loss = 0.000070
# Iteration 462: Loss = 0.000069
# Iteration 463: Loss = 0.000068
# Iteration 464: Loss = 0.000067
# Iteration 465: Loss = 0.000066
# Iteration 466: Loss = 0.000065
# Iteration 467: Loss = 0.000064
# Iteration 468: Loss = 0.000063
# Iteration 469: Loss = 0.000063
# Iteration 470: Loss = 0.000062
# Iteration 471: Loss = 0.000061
# Iteration 472: Loss = 0.000060
# Iteration 473: Loss = 0.000059
# Iteration 474: Loss = 0.000058
# Iteration 475: Loss = 0.000058
# Iteration 476: Loss = 0.000057
# Iteration 477: Loss = 0.000056
# Iteration 478: Loss = 0.000055
# Iteration 479: Loss = 0.000055
# Iteration 480: Loss = 0.000054
# Iteration 481: Loss = 0.000053
# Iteration 482: Loss = 0.000053
# Iteration 483: Loss = 0.000052
# Iteration 484: Loss = 0.000051
# Iteration 485: Loss = 0.000051
# Iteration 486: Loss = 0.000050
# Iteration 487: Loss = 0.000050
# Iteration 488: Loss = 0.000049
# Iteration 489: Loss = 0.000048
# Iteration 490: Loss = 0.000048
# Iteration 491: Loss = 0.000047
# Iteration 492: Loss = 0.000047
# Iteration 493: Loss = 0.000046
# Iteration 494: Loss = 0.000046
# Iteration 495: Loss = 0.000045
# Iteration 496: Loss = 0.000044
# Iteration 497: Loss = 0.000044
# Iteration 498: Loss = 0.000043
# Iteration 499: Loss = 0.000043

# %% [markdown]
# ##PyTorch: nn
# Computational graphs and autograd are a very powerful paradigm for defining complex operators and automatically taking derivatives; however for large neural networks raw autograd can be a bit too low-level.
#
# When building neural networks we frequently think of arranging the computation into layers, some of which have learnable parameters which will be optimized during learning.
#
# In TensorFlow, packages like Keras, TensorFlow-Slim, and TFLearn provide higher-level abstractions over raw computational graphs that are useful for building neural networks.
#
# In PyTorch, the nn package serves this same purpose. The nn package defines a set of Modules, which are roughly equivalent to neural network layers. A Module receives input Tensors and computes output Tensors, but may also hold internal state such as Tensors containing learnable parameters. The nn package also defines a set of useful loss functions that are commonly used when training neural networks.
#
# In this example we use the nn package to implement our two-layer network:

# %%
# Code in file nn/two_layer_net_nn.py
import torch

device = torch.device('cpu')
#device = torch.device('cuda') # Uncomment this to run on GPU

# N is batch size; D_in is input dimension;
# H is hidden dimension; D_out is output dimension.
N, D_in, H, D_out = 64, 1000, 100, 10

# Create random Tensors to hold inputs and outputs
x = torch.randn(N, D_in, device=device)
y = torch.randn(N, D_out, device=device)

# Use the nn package to define our model as a sequence of layers. nn.Sequential
# is a Module which contains other Modules, and applies them in sequence to
# produce its output. Each Linear Module computes output from input using a
# linear function, and holds internal Tensors for its weight and bias.
# After constructing the model we use the .to() method to move it to the
# desired device.
model = torch.nn.Sequential(
          torch.nn.Linear(D_in, H),
          torch.nn.ReLU(),
          torch.nn.Linear(H, D_out),
        ).to(device)

# The nn package also contains definitions of popular loss functions; in this
# case we will use Mean Squared Error (MSE) as our loss function. Setting
# reduction='sum' means that we are computing the *sum* of squared errors rather
# than the mean; this is for consistency with the examples above where we
# manually compute the loss, but in practice it is more common to use mean
# squared error as a loss by setting reduction='elementwise_mean'.
loss_fn = torch.nn.MSELoss(reduction='sum')

learning_rate = 1e-4
for t in range(500):
  # Forward pass: compute predicted y by passing x to the model. Module objects
  # override the __call__ operator so you can call them like functions. When
  # doing so you pass a Tensor of input data to the Module and it produces
  # a Tensor of output data.
  y_pred = model(x)

  # Compute and print loss. We pass Tensors containing the predicted and true
  # values of y, and the loss function returns a Tensor containing the loss.
  loss = loss_fn(y_pred, y)
  print(f"Iteration {t}: Loss = {loss.item():.6f}")

  # Zero the gradients before running the backward pass.
  model.zero_grad()

  # Backward pass: compute gradient of the loss with respect to all the learnable
  # parameters of the model. Internally, the parameters of each Module are stored
  # in Tensors with requires_grad=True, so this call will compute gradients for
  # all learnable parameters in the model.
  loss.backward()

  # Update the weights using gradient descent. Each parameter is a Tensor, so
  # we can access its data and gradients like we did before.
  with torch.no_grad():
    for param in model.parameters():
      param.data -= learning_rate * param.grad
# Out:
# Iteration 0: Loss = 719.143799
# Iteration 1: Loss = 665.955078
# Iteration 2: Loss = 620.433655
# Iteration 3: Loss = 580.002136
# Iteration 4: Loss = 543.803955
# Iteration 5: Loss = 511.173065
# Iteration 6: Loss = 481.436554
# Iteration 7: Loss = 454.657715
# Iteration 8: Loss = 430.189301
# Iteration 9: Loss = 407.492371
# Iteration 10: Loss = 386.327820
# Iteration 11: Loss = 366.391663
# Iteration 12: Loss = 347.479919
# Iteration 13: Loss = 329.527100
# Iteration 14: Loss = 312.512482
# Iteration 15: Loss = 296.303741
# Iteration 16: Loss = 280.661224
# Iteration 17: Loss = 265.734741
# Iteration 18: Loss = 251.484192
# Iteration 19: Loss = 237.879181
# Iteration 20: Loss = 224.893600
# Iteration 21: Loss = 212.535049
# Iteration 22: Loss = 200.766052
# Iteration 23: Loss = 189.582733
# Iteration 24: Loss = 178.945358
# Iteration 25: Loss = 168.841995
# Iteration 26: Loss = 159.214355
# Iteration 27: Loss = 150.069473
# Iteration 28: Loss = 141.398544
# Iteration 29: Loss = 133.172226
# Iteration 30: Loss = 125.369186
# Iteration 31: Loss = 117.991554
# Iteration 32: Loss = 110.994347
# Iteration 33: Loss = 104.388817
# Iteration 34: Loss = 98.150986
# Iteration 35: Loss = 92.269859
# Iteration 36: Loss = 86.712631
# Iteration 37: Loss = 81.485519
# Iteration 38: Loss = 76.565201
# Iteration 39: Loss = 71.926178
# Iteration 40: Loss = 67.566643
# Iteration 41: Loss = 63.463448
# Iteration 42: Loss = 59.610367
# Iteration 43: Loss = 55.992523
# Iteration 44: Loss = 52.601578
# Iteration 45: Loss = 49.418144
# Iteration 46: Loss = 46.432190
# Iteration 47: Loss = 43.631519
# Iteration 48: Loss = 41.007236
# Iteration 49: Loss = 38.542980
# Iteration 50: Loss = 36.236275
# Iteration 51: Loss = 34.078445
# Iteration 52: Loss = 32.055470
# Iteration 53: Loss = 30.136772
# Iteration 54: Loss = 28.339487
# Iteration 55: Loss = 26.655428
# Iteration 56: Loss = 25.077158
# Iteration 57: Loss = 23.597540
# Iteration 58: Loss = 22.214520
# Iteration 59: Loss = 20.914375
# Iteration 60: Loss = 19.696281
# Iteration 61: Loss = 18.554909
# Iteration 62: Loss = 17.481527
# Iteration 63: Loss = 16.469135
# Iteration 64: Loss = 15.519526
# Iteration 65: Loss = 14.631533
# Iteration 66: Loss = 13.797149
# Iteration 67: Loss = 13.014359
# Iteration 68: Loss = 12.279333
# Iteration 69: Loss = 11.588332
# Iteration 70: Loss = 10.938450
# Iteration 71: Loss = 10.328460
# Iteration 72: Loss = 9.754298
# Iteration 73: Loss = 9.213372
# Iteration 74: Loss = 8.705153
# Iteration 75: Loss = 8.226629
# Iteration 76: Loss = 7.776531
# Iteration 77: Loss = 7.352428
# Iteration 78: Loss = 6.953428
# Iteration 79: Loss = 6.577503
# Iteration 80: Loss = 6.223793
# Iteration 81: Loss = 5.890394
# Iteration 82: Loss = 5.576233
# Iteration 83: Loss = 5.280515
# Iteration 84: Loss = 5.001384
# Iteration 85: Loss = 4.737843
# Iteration 86: Loss = 4.489899
# Iteration 87: Loss = 4.255662
# Iteration 88: Loss = 4.034586
# Iteration 89: Loss = 3.825728
# Iteration 90: Loss = 3.628231
# Iteration 91: Loss = 3.441783
# Iteration 92: Loss = 3.265662
# Iteration 93: Loss = 3.099128
# Iteration 94: Loss = 2.941566
# Iteration 95: Loss = 2.792543
# Iteration 96: Loss = 2.651680
# Iteration 97: Loss = 2.518331
# Iteration 98: Loss = 2.391964
# Iteration 99: Loss = 2.272346
# Iteration 100: Loss = 2.159131
# Iteration 101: Loss = 2.051959
# Iteration 102: Loss = 1.950476
# Iteration 103: Loss = 1.854288
# Iteration 104: Loss = 1.763208
# Iteration 105: Loss = 1.676793
# Iteration 106: Loss = 1.594754
# Iteration 107: Loss = 1.517057
# Iteration 108: Loss = 1.443426
# Iteration 109: Loss = 1.373473
# Iteration 110: Loss = 1.307158
# Iteration 111: Loss = 1.244221
# Iteration 112: Loss = 1.184480
# Iteration 113: Loss = 1.127696
# Iteration 114: Loss = 1.073826
# Iteration 115: Loss = 1.022703
# Iteration 116: Loss = 0.974119
# Iteration 117: Loss = 0.928022
# Iteration 118: Loss = 0.884141
# Iteration 119: Loss = 0.842487
# Iteration 120: Loss = 0.802918
# Iteration 121: Loss = 0.765257
# Iteration 122: Loss = 0.729469
# Iteration 123: Loss = 0.695506
# Iteration 124: Loss = 0.663160
# Iteration 125: Loss = 0.632421
# Iteration 126: Loss = 0.603160
# Iteration 127: Loss = 0.575348
# Iteration 128: Loss = 0.548857
# Iteration 129: Loss = 0.523702
# Iteration 130: Loss = 0.499743
# Iteration 131: Loss = 0.476961
# Iteration 132: Loss = 0.455255
# Iteration 133: Loss = 0.434627
# Iteration 134: Loss = 0.414931
# Iteration 135: Loss = 0.396195
# Iteration 136: Loss = 0.378340
# Iteration 137: Loss = 0.361329
# Iteration 138: Loss = 0.345131
# Iteration 139: Loss = 0.329702
# Iteration 140: Loss = 0.314985
# Iteration 141: Loss = 0.300967
# Iteration 142: Loss = 0.287627
# Iteration 143: Loss = 0.274947
# Iteration 144: Loss = 0.262864
# Iteration 145: Loss = 0.251340
# Iteration 146: Loss = 0.240380
# Iteration 147: Loss = 0.229909
# Iteration 148: Loss = 0.219911
# Iteration 149: Loss = 0.210376
# Iteration 150: Loss = 0.201269
# Iteration 151: Loss = 0.192582
# Iteration 152: Loss = 0.184298
# Iteration 153: Loss = 0.176379
# Iteration 154: Loss = 0.168823
# Iteration 155: Loss = 0.161605
# Iteration 156: Loss = 0.154708
# Iteration 157: Loss = 0.148129
# Iteration 158: Loss = 0.141842
# Iteration 159: Loss = 0.135831
# Iteration 160: Loss = 0.130099
# Iteration 161: Loss = 0.124621
# Iteration 162: Loss = 0.119383
# Iteration 163: Loss = 0.114370
# Iteration 164: Loss = 0.109583
# Iteration 165: Loss = 0.105004
# Iteration 166: Loss = 0.100622
# Iteration 167: Loss = 0.096438
# Iteration 168: Loss = 0.092432
# Iteration 169: Loss = 0.088601
# Iteration 170: Loss = 0.084939
# Iteration 171: Loss = 0.081433
# Iteration 172: Loss = 0.078080
# Iteration 173: Loss = 0.074874
# Iteration 174: Loss = 0.071808
# Iteration 175: Loss = 0.068864
# Iteration 176: Loss = 0.066046
# Iteration 177: Loss = 0.063348
# Iteration 178: Loss = 0.060765
# Iteration 179: Loss = 0.058295
# Iteration 180: Loss = 0.055932
# Iteration 181: Loss = 0.053669
# Iteration 182: Loss = 0.051499
# Iteration 183: Loss = 0.049422
# Iteration 184: Loss = 0.047435
# Iteration 185: Loss = 0.045535
# Iteration 186: Loss = 0.043713
# Iteration 187: Loss = 0.041967
# Iteration 188: Loss = 0.040296
# Iteration 189: Loss = 0.038693
# Iteration 190: Loss = 0.037154
# Iteration 191: Loss = 0.035680
# Iteration 192: Loss = 0.034269
# Iteration 193: Loss = 0.032916
# Iteration 194: Loss = 0.031618
# Iteration 195: Loss = 0.030373
# Iteration 196: Loss = 0.029179
# Iteration 197: Loss = 0.028036
# Iteration 198: Loss = 0.026940
# Iteration 199: Loss = 0.025886
# Iteration 200: Loss = 0.024875
# Iteration 201: Loss = 0.023906
# Iteration 202: Loss = 0.022977
# Iteration 203: Loss = 0.022084
# Iteration 204: Loss = 0.021228
# Iteration 205: Loss = 0.020407
# Iteration 206: Loss = 0.019618
# Iteration 207: Loss = 0.018860
# Iteration 208: Loss = 0.018135
# Iteration 209: Loss = 0.017437
# Iteration 210: Loss = 0.016767
# Iteration 211: Loss = 0.016124
# Iteration 212: Loss = 0.015507
# Iteration 213: Loss = 0.014915
# Iteration 214: Loss = 0.014346
# Iteration 215: Loss = 0.013800
# Iteration 216: Loss = 0.013275
# Iteration 217: Loss = 0.012771
# Iteration 218: Loss = 0.012287
# Iteration 219: Loss = 0.011823
# Iteration 220: Loss = 0.011376
# Iteration 221: Loss = 0.010947
# Iteration 222: Loss = 0.010534
# Iteration 223: Loss = 0.010138
# Iteration 224: Loss = 0.009757
# Iteration 225: Loss = 0.009391
# Iteration 226: Loss = 0.009040
# Iteration 227: Loss = 0.008701
# Iteration 228: Loss = 0.008376
# Iteration 229: Loss = 0.008064
# Iteration 230: Loss = 0.007763
# Iteration 231: Loss = 0.007475
# Iteration 232: Loss = 0.007197
# Iteration 233: Loss = 0.006930
# Iteration 234: Loss = 0.006673
# Iteration 235: Loss = 0.006426
# Iteration 236: Loss = 0.006188
# Iteration 237: Loss = 0.005959
# Iteration 238: Loss = 0.005740
# Iteration 239: Loss = 0.005528
# Iteration 240: Loss = 0.005325
# Iteration 241: Loss = 0.005129
# Iteration 242: Loss = 0.004941
# Iteration 243: Loss = 0.004760
# Iteration 244: Loss = 0.004586
# Iteration 245: Loss = 0.004418
# Iteration 246: Loss = 0.004257
# Iteration 247: Loss = 0.004102
# Iteration 248: Loss = 0.003952
# Iteration 249: Loss = 0.003808
# Iteration 250: Loss = 0.003670
# Iteration 251: Loss = 0.003537
# Iteration 252: Loss = 0.003408
# Iteration 253: Loss = 0.003285
# Iteration 254: Loss = 0.003166
# Iteration 255: Loss = 0.003051
# Iteration 256: Loss = 0.002941
# Iteration 257: Loss = 0.002835
# Iteration 258: Loss = 0.002733
# Iteration 259: Loss = 0.002635
# Iteration 260: Loss = 0.002539
# Iteration 261: Loss = 0.002447
# Iteration 262: Loss = 0.002358
# Iteration 263: Loss = 0.002273
# Iteration 264: Loss = 0.002191
# Iteration 265: Loss = 0.002112
# Iteration 266: Loss = 0.002036
# Iteration 267: Loss = 0.001963
# Iteration 268: Loss = 0.001892
# Iteration 269: Loss = 0.001824
# Iteration 270: Loss = 0.001759
# Iteration 271: Loss = 0.001696
# Iteration 272: Loss = 0.001635
# Iteration 273: Loss = 0.001576
# Iteration 274: Loss = 0.001520
# Iteration 275: Loss = 0.001466
# Iteration 276: Loss = 0.001414
# Iteration 277: Loss = 0.001364
# Iteration 278: Loss = 0.001315
# Iteration 279: Loss = 0.001268
# Iteration 280: Loss = 0.001223
# Iteration 281: Loss = 0.001180
# Iteration 282: Loss = 0.001138
# Iteration 283: Loss = 0.001098
# Iteration 284: Loss = 0.001059
# Iteration 285: Loss = 0.001022
# Iteration 286: Loss = 0.000986
# Iteration 287: Loss = 0.000951
# Iteration 288: Loss = 0.000918
# Iteration 289: Loss = 0.000885
# Iteration 290: Loss = 0.000854
# Iteration 291: Loss = 0.000824
# Iteration 292: Loss = 0.000796
# Iteration 293: Loss = 0.000768
# Iteration 294: Loss = 0.000741
# Iteration 295: Loss = 0.000715
# Iteration 296: Loss = 0.000690
# Iteration 297: Loss = 0.000666
# Iteration 298: Loss = 0.000643
# Iteration 299: Loss = 0.000620
# Iteration 300: Loss = 0.000599
# Iteration 301: Loss = 0.000578
# Iteration 302: Loss = 0.000558
# Iteration 303: Loss = 0.000539
# Iteration 304: Loss = 0.000520
# Iteration 305: Loss = 0.000502
# Iteration 306: Loss = 0.000485
# Iteration 307: Loss = 0.000468
# Iteration 308: Loss = 0.000452
# Iteration 309: Loss = 0.000436
# Iteration 310: Loss = 0.000421
# Iteration 311: Loss = 0.000407
# Iteration 312: Loss = 0.000393
# Iteration 313: Loss = 0.000379
# Iteration 314: Loss = 0.000366
# Iteration 315: Loss = 0.000353
# Iteration 316: Loss = 0.000341
# Iteration 317: Loss = 0.000330
# Iteration 318: Loss = 0.000318
# Iteration 319: Loss = 0.000307
# Iteration 320: Loss = 0.000297
# Iteration 321: Loss = 0.000287
# Iteration 322: Loss = 0.000277
# Iteration 323: Loss = 0.000268
# Iteration 324: Loss = 0.000258
# Iteration 325: Loss = 0.000250
# Iteration 326: Loss = 0.000241
# Iteration 327: Loss = 0.000233
# Iteration 328: Loss = 0.000225
# Iteration 329: Loss = 0.000217
# Iteration 330: Loss = 0.000210
# Iteration 331: Loss = 0.000203
# Iteration 332: Loss = 0.000196
# Iteration 333: Loss = 0.000189
# Iteration 334: Loss = 0.000183
# Iteration 335: Loss = 0.000177
# Iteration 336: Loss = 0.000171
# Iteration 337: Loss = 0.000165
# Iteration 338: Loss = 0.000159
# Iteration 339: Loss = 0.000154
# Iteration 340: Loss = 0.000149
# Iteration 341: Loss = 0.000144
# Iteration 342: Loss = 0.000139
# Iteration 343: Loss = 0.000134
# Iteration 344: Loss = 0.000130
# Iteration 345: Loss = 0.000125
# Iteration 346: Loss = 0.000121
# Iteration 347: Loss = 0.000117
# Iteration 348: Loss = 0.000113
# Iteration 349: Loss = 0.000109
# Iteration 350: Loss = 0.000106
# Iteration 351: Loss = 0.000102
# Iteration 352: Loss = 0.000099
# Iteration 353: Loss = 0.000096
# Iteration 354: Loss = 0.000092
# Iteration 355: Loss = 0.000089
# Iteration 356: Loss = 0.000086
# Iteration 357: Loss = 0.000083
# Iteration 358: Loss = 0.000081
# Iteration 359: Loss = 0.000078
# Iteration 360: Loss = 0.000075
# Iteration 361: Loss = 0.000073
# Iteration 362: Loss = 0.000070
# Iteration 363: Loss = 0.000068
# Iteration 364: Loss = 0.000066
# Iteration 365: Loss = 0.000064
# Iteration 366: Loss = 0.000062
# Iteration 367: Loss = 0.000059
# Iteration 368: Loss = 0.000058
# Iteration 369: Loss = 0.000056
# Iteration 370: Loss = 0.000054
# Iteration 371: Loss = 0.000052
# Iteration 372: Loss = 0.000050
# Iteration 373: Loss = 0.000049
# Iteration 374: Loss = 0.000047
# Iteration 375: Loss = 0.000045
# Iteration 376: Loss = 0.000044
# Iteration 377: Loss = 0.000043
# Iteration 378: Loss = 0.000041
# Iteration 379: Loss = 0.000040
# Iteration 380: Loss = 0.000038
# Iteration 381: Loss = 0.000037
# Iteration 382: Loss = 0.000036
# Iteration 383: Loss = 0.000035
# Iteration 384: Loss = 0.000034
# Iteration 385: Loss = 0.000033
# Iteration 386: Loss = 0.000031
# Iteration 387: Loss = 0.000030
# Iteration 388: Loss = 0.000029
# Iteration 389: Loss = 0.000028
# Iteration 390: Loss = 0.000028
# Iteration 391: Loss = 0.000027
# Iteration 392: Loss = 0.000026
# Iteration 393: Loss = 0.000025
# Iteration 394: Loss = 0.000024
# Iteration 395: Loss = 0.000023
# Iteration 396: Loss = 0.000023
# Iteration 397: Loss = 0.000022
# Iteration 398: Loss = 0.000021
# Iteration 399: Loss = 0.000020
# Iteration 400: Loss = 0.000020
# Iteration 401: Loss = 0.000019
# Iteration 402: Loss = 0.000019
# Iteration 403: Loss = 0.000018
# Iteration 404: Loss = 0.000017
# Iteration 405: Loss = 0.000017
# Iteration 406: Loss = 0.000016
# Iteration 407: Loss = 0.000016
# Iteration 408: Loss = 0.000015
# Iteration 409: Loss = 0.000015
# Iteration 410: Loss = 0.000014
# Iteration 411: Loss = 0.000014
# Iteration 412: Loss = 0.000013
# Iteration 413: Loss = 0.000013
# Iteration 414: Loss = 0.000012
# Iteration 415: Loss = 0.000012
# Iteration 416: Loss = 0.000012
# Iteration 417: Loss = 0.000011
# Iteration 418: Loss = 0.000011
# Iteration 419: Loss = 0.000011
# Iteration 420: Loss = 0.000010
# Iteration 421: Loss = 0.000010
# Iteration 422: Loss = 0.000010
# Iteration 423: Loss = 0.000009
# Iteration 424: Loss = 0.000009
# Iteration 425: Loss = 0.000009
# Iteration 426: Loss = 0.000008
# Iteration 427: Loss = 0.000008
# Iteration 428: Loss = 0.000008
# Iteration 429: Loss = 0.000008
# Iteration 430: Loss = 0.000007
# Iteration 431: Loss = 0.000007
# Iteration 432: Loss = 0.000007
# Iteration 433: Loss = 0.000007
# Iteration 434: Loss = 0.000006
# Iteration 435: Loss = 0.000006
# Iteration 436: Loss = 0.000006
# Iteration 437: Loss = 0.000006
# Iteration 438: Loss = 0.000006
# Iteration 439: Loss = 0.000006
# Iteration 440: Loss = 0.000005
# Iteration 441: Loss = 0.000005
# Iteration 442: Loss = 0.000005
# Iteration 443: Loss = 0.000005
# Iteration 444: Loss = 0.000005
# Iteration 445: Loss = 0.000005
# Iteration 446: Loss = 0.000004
# Iteration 447: Loss = 0.000004
# Iteration 448: Loss = 0.000004
# Iteration 449: Loss = 0.000004
# Iteration 450: Loss = 0.000004
# Iteration 451: Loss = 0.000004
# Iteration 452: Loss = 0.000004
# Iteration 453: Loss = 0.000003
# Iteration 454: Loss = 0.000003
# Iteration 455: Loss = 0.000003
# Iteration 456: Loss = 0.000003
# Iteration 457: Loss = 0.000003
# Iteration 458: Loss = 0.000003
# Iteration 459: Loss = 0.000003
# Iteration 460: Loss = 0.000003
# Iteration 461: Loss = 0.000003
# Iteration 462: Loss = 0.000003
# Iteration 463: Loss = 0.000003
# Iteration 464: Loss = 0.000002
# Iteration 465: Loss = 0.000002
# Iteration 466: Loss = 0.000002
# Iteration 467: Loss = 0.000002
# Iteration 468: Loss = 0.000002
# Iteration 469: Loss = 0.000002
# Iteration 470: Loss = 0.000002
# Iteration 471: Loss = 0.000002
# Iteration 472: Loss = 0.000002
# Iteration 473: Loss = 0.000002
# Iteration 474: Loss = 0.000002
# Iteration 475: Loss = 0.000002
# Iteration 476: Loss = 0.000002
# Iteration 477: Loss = 0.000002
# Iteration 478: Loss = 0.000002
# Iteration 479: Loss = 0.000002
# Iteration 480: Loss = 0.000001
# Iteration 481: Loss = 0.000001
# Iteration 482: Loss = 0.000001
# Iteration 483: Loss = 0.000001
# Iteration 484: Loss = 0.000001
# Iteration 485: Loss = 0.000001
# Iteration 486: Loss = 0.000001
# Iteration 487: Loss = 0.000001
# Iteration 488: Loss = 0.000001
# Iteration 489: Loss = 0.000001
# Iteration 490: Loss = 0.000001
# Iteration 491: Loss = 0.000001
# Iteration 492: Loss = 0.000001
# Iteration 493: Loss = 0.000001
# Iteration 494: Loss = 0.000001
# Iteration 495: Loss = 0.000001
# Iteration 496: Loss = 0.000001
# Iteration 497: Loss = 0.000001
# Iteration 498: Loss = 0.000001
# Iteration 499: Loss = 0.000001

# %% [markdown]
# # **Training a 3-Layer MLP on the MNIST Dataset Using PyTorch**

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torchvision.datasets import MNIST
from torch.utils.data import DataLoader

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Hyperparameters
num_epochs = 10
batch_size = 100
learning_rate = 0.001
input_size = 28 * 28  # MNIST images are 28x28 pixels
hidden_size_1 = 128  # Number of neurons in hidden layers-1
hidden_size_2 = 64   # Number of neurons in hidden layers-2
num_classes = 10  # Digits 0-9

# %%
# MNIST dataset
train_dataset = MNIST(root='./data', train=True, transform=transforms.ToTensor(), download=True)
test_dataset = MNIST(root='./data', train=False, transform=transforms.ToTensor())

# Data loader
train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 17.8MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 484kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.47MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 7.72MB/s]

# %%
# Define the ANN model
class ANN(nn.Module):
    def __init__(self):
        super(ANN, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size_1)
        self.relu1 = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size_1, hidden_size_2)
        self.relu2 = nn.ReLU()
        self.fc3 = nn.Linear(hidden_size_2, num_classes)

    def forward(self, x):
        x = x.view(-1, input_size)  # Flatten the image
        x = self.fc1(x)
        x = self.relu1(x)
        x = self.fc2(x)
        x = self.relu2(x)
        x = self.fc3(x)
        return x

# %%
# Initialize model
model = ANN().to(device)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# Training the model
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)

        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)

        # Backward and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if (i+1) % 100 == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{len(train_loader)}], Loss: {loss.item():.4f}')

print('Training finished.')
# Out:
# Epoch [1/10], Step [100/600], Loss: 0.4727
# Epoch [1/10], Step [200/600], Loss: 0.4453
# Epoch [1/10], Step [300/600], Loss: 0.2940
# Epoch [1/10], Step [400/600], Loss: 0.1269
# Epoch [1/10], Step [500/600], Loss: 0.1609
# Epoch [1/10], Step [600/600], Loss: 0.1834
# Epoch [2/10], Step [100/600], Loss: 0.1584
# Epoch [2/10], Step [200/600], Loss: 0.0984
# Epoch [2/10], Step [300/600], Loss: 0.1417
# Epoch [2/10], Step [400/600], Loss: 0.0674
# Epoch [2/10], Step [500/600], Loss: 0.1066
# Epoch [2/10], Step [600/600], Loss: 0.1027
# Epoch [3/10], Step [100/600], Loss: 0.0859
# Epoch [3/10], Step [200/600], Loss: 0.1533
# Epoch [3/10], Step [300/600], Loss: 0.1169
# Epoch [3/10], Step [400/600], Loss: 0.0524
# Epoch [3/10], Step [500/600], Loss: 0.1114
# Epoch [3/10], Step [600/600], Loss: 0.0639
# Epoch [4/10], Step [100/600], Loss: 0.0407
# Epoch [4/10], Step [200/600], Loss: 0.0457
# Epoch [4/10], Step [300/600], Loss: 0.1354
# Epoch [4/10], Step [400/600], Loss: 0.0545
# Epoch [4/10], Step [500/600], Loss: 0.0579
# Epoch [4/10], Step [600/600], Loss: 0.1948
# Epoch [5/10], Step [100/600], Loss: 0.0512
# Epoch [5/10], Step [200/600], Loss: 0.0224
# Epoch [5/10], Step [300/600], Loss: 0.0643
# Epoch [5/10], Step [400/600], Loss: 0.0280
# Epoch [5/10], Step [500/600], Loss: 0.0192
# Epoch [5/10], Step [600/600], Loss: 0.0697
# Epoch [6/10], Step [100/600], Loss: 0.0151
# Epoch [6/10], Step [200/600], Loss: 0.0479
# Epoch [6/10], Step [300/600], Loss: 0.0470
# Epoch [6/10], Step [400/600], Loss: 0.1160
# Epoch [6/10], Step [500/600], Loss: 0.0267
# Epoch [6/10], Step [600/600], Loss: 0.1524
# Epoch [7/10], Step [100/600], Loss: 0.0388
# Epoch [7/10], Step [200/600], Loss: 0.1479
# Epoch [7/10], Step [300/600], Loss: 0.0567
# Epoch [7/10], Step [400/600], Loss: 0.0466
# Epoch [7/10], Step [500/600], Loss: 0.0210
# Epoch [7/10], Step [600/600], Loss: 0.0171
# Epoch [8/10], Step [100/600], Loss: 0.1155
# Epoch [8/10], Step [200/600], Loss: 0.0271
# Epoch [8/10], Step [300/600], Loss: 0.0182
# Epoch [8/10], Step [400/600], Loss: 0.0173
# Epoch [8/10], Step [500/600], Loss: 0.0070
# Epoch [8/10], Step [600/600], Loss: 0.0120
# Epoch [9/10], Step [100/600], Loss: 0.0307
# Epoch [9/10], Step [200/600], Loss: 0.0159
# Epoch [9/10], Step [300/600], Loss: 0.0209
# Epoch [9/10], Step [400/600], Loss: 0.0409
# Epoch [9/10], Step [500/600], Loss: 0.0091
# Epoch [9/10], Step [600/600], Loss: 0.0037
# Epoch [10/10], Step [100/600], Loss: 0.0061
# Epoch [10/10], Step [200/600], Loss: 0.0093
# Epoch [10/10], Step [300/600], Loss: 0.0019
# Epoch [10/10], Step [400/600], Loss: 0.0256
# Epoch [10/10], Step [500/600], Loss: 0.0034
# Epoch [10/10], Step [600/600], Loss: 0.0101
# Training finished.

# %%
# Testing the model
model.eval()
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    print(f'Accuracy on the test images: {100 * correct / total:.2f}%')
# Out:
# Accuracy on the test images: 97.90%
